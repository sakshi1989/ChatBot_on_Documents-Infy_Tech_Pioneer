# %%
from langchain.text_splitter import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf
from pprint import pprint
import fitz
import tesserocr
from PIL import Image
import re
from ollama import generate
from unidecode import unidecode
import easyocr

# %%
# %env EXTRACT_IMAGE_BLOCK_CROP_HORIZONTAL_PAD=100
# %env EXTRACT_IMAGE_BLOCK_CROP_VERTICAL_PAD=100
# Out:
# env: EXTRACT_IMAGE_BLOCK_CROP_HORIZONTAL_PAD=100
# env: EXTRACT_IMAGE_BLOCK_CROP_VERTICAL_PAD=100

# %%
# Extract elements from PDF
def extract_pdf_elements(path, fname, image_path):
    """
    Extract images, tables, and chunk text from a PDF file.
    path: File path to extract PDF documents
    fname: File name
    image_path: Path to save images
    """
    return partition_pdf(
        filename=path + fname,    
        strategy='hi_res',  
        infer_table_structure=True,
        # chunking_strategy="by_title",
        hi_res_model_name = 'detectron2_onnx', 
        extract_image_block_types=["Image", "Table","Figure"],
        extract_image_block_output_dir=image_path,
        # max_characters=4000,
        # new_after_n_chars=3800,
        # combine_text_under_n_chars=2000,
    )

# %%
# Process the Wf document
# File path
fpath = "files/"
fname = "2022-annual-report-wf.pdf"
image_path = "data1"

# Get elements
raw_pdf_elements = extract_pdf_elements(fpath, fname,image_path)
# Out:
# Sak detectron2_onnx

# %%
# for element in raw_pdf_elements:
#     print(element.category, ' : ', element.text)
# Out:
# UncategorizedText  :  2022
# Title  :  Annual Report
# NarrativeText  :  Wells Fargo & Company
# Title  :  WELLS FARGO
# Title  :  CEO Letter
# NarrativeText  :  Dear Shareholders,
# NarrativeText  :  I’m proud to report that Wells Fargo continued to make progress on our priorities in 2022. Our underlying financial performance is improving, we are moving forward on our risk, control and regulatory agenda, we are focusing on businesses where we can generate appropriate risk-adjusted returns, we continue to strengthen the leadership team, and we are executing on our strategic objectives. While we have made progress, our work is not complete and we remain focused on successful and timely execution of our multi-year journey to complete our risk and control work and to move forward with our businesses.
# Title  :  Stronger financial performance
# NarrativeText  :  Our financial performance benefitted as we continued to drive improved efficiency, and it was positively impacted by both rising rates and a benign credit environment.
# NarrativeText  :  In 2022, Wells Fargo generated $13.2 billion in net income, or $3.17 per common share. Our results were significantly impacted by $7 billion of operating losses, primarily related to putting historical issues behind us, including litigation, regulatory matters, and customer remediations. However, our performance excluding those items was solid and demonstrates the continued progress we are making to improve returns.
# NarrativeText  :  Our revenue decreased 6% from the previous year. The higher rate environment and good loan growth drove strong growth in net interest income, which was up 26% from a year ago. However, this growth was more than offset by lower net gains from equity securities, mortgage banking, and investment advisory and other asset-based fees reflecting market conditions, as well as the lost revenue related to businesses we sold in 2021.
# NarrativeText  :  Expenses increased 6% from a year ago, reflecting higher operating losses primarily related to putting historical matters behind us, as noted above. Excluding operating losses, noninterest expense declined from a year ago, reflecting continued progress on our efficiency initiatives and the impact from business sales. We achieved these efficiency gains while we made continued investments in our risk and control infrastructure and in strategic initiatives across our businesses, and in the face of continued inflationary pressures.
# NarrativeText  :  Credit quality remained strong, but, as expected, losses started to slowly increase in the second half of the year off their
# NarrativeText  :  historical lows. Our net charge-off rate declined from 18 basis points in 2021 to 17 basis points in 2022, and our allowance for credit losses declined by $75 million in 2022, as our reserve release in the first quarter was slightly larger than the reserve builds we had in the last three quarters of the year.
# NarrativeText  :  Loans outstanding increased by 7% from one year ago, with growth in both our consumer and commercial portfolios. Consumer Banking and Lending grew 4%, driven by growth in residential mortgage and credit card, which offset a decline in auto loans. Both Commercial Banking and Corporate and Investment Banking had strong loan growth, with commercial loans up 9% from a year ago, driven by growth across all asset classes. Average deposits in 2022 decreased 1% to $1.42 trillion, as higher market rates spurred customers to look for higher yielding alternatives, and consumers continued to spend savings that built up during the pandemic.
# NarrativeText  :  Our capital levels remained well above our required regulatory minimums plus buffers. We increased our quarterly common stock dividend in the first quarter of 2022 from $0.20 per share to $0.25 per share and then to $0.30 in the third quarter of 2022. While we did not repurchase any common stock in the last three quarters of 2022, we have repurchased shares in the first quarter of 2023.
# NarrativeText  :  Our return on equity was 7.5% and our return on tangible common equity (ROTCE) was 9.0%1. Both of these ratios were impacted by the operating losses I highlighted earlier.
# NarrativeText  :  In my shareholder letter over the past two years, I have discussed our path to higher returns. Since 2020, we have executed on a number of important items to improve our returns, including returning $16 billion to shareholders through net common stock repurchases, increasing our common stock dividend from $0.10 per share to $0.30 per share, and delivering approximately $7.5 billion of gross expense saves. Based on these actions and others that are in flight, we believe we have a clear line of sight to a sustainable ROTCE of approximately 15% in the medium term. In order to achieve that, we need to continue to optimize our capital, including returning capital to shareholders and redeploying capital to higher returning businesses; execute on efficiency initiatives; and benefit from the investments we are making in our businesses.
# ListItem  :  1 Return on tangible common equity (ROTCE) is a non-GAAP financial measure. For additional information, including a corresponding reconciliation to GAAP financial measures, see the “Financial Review – Capital Management – Tangible Common Equity” section in this Report.
# Title  :  2022 Annual Report
# Title  :  i
# Title  :  We are actively watching the economy
# Title  :  Consumers
# NarrativeText  :  After a period of strong economic growth and low unemployment, the Federal Reserve has been increasing interest rates aggressively with a goal of combatting high inflation. Increasing interest rates and a slowing economy have caused headwinds for some of our customers, but our customers have largely remained resilient over the past year, with deposit balances, consumer spending and credit quality still stronger than pre-pandemic levels.
# NarrativeText  :  Consumer credit card spend continued to be strong in 2022, with spending up 25% compared with 2021, which reflects the benefit of new Wells Fargo product launches. Almost all spending categories had double-digit spend growth year over year. Consumer debit card spend slowed to 3% growth in 2022 compared to 2021. Growth was driven by ticket size since transaction volume was flat year-over-year, and discretionary spend outpaced non-discretionary spend.
# NarrativeText  :  At the same time, we are carefully watching the impact of higher rates and we expect to see deposit balances continue to decrease and credit quality to continue to weaken. For certain cohorts of customers, average deposit balances are below pre-pandemic levels, and we are closely monitoring activity for signs of potential stress. For our borrowers, we are working to limit the risk – both to them and to us – of overextension. We have taken selective actions across our consumer lending businesses to mitigate risks associated with inflation and increased debt leverage. In our auto business, we have adjusted policies to address risk associated with collateral value declines and inflationary pressures on consumers’ ability to pay. In home lending, we have tightened loan-to-value policies nationally and even more so in local markets that have elevated home value risk. Additionally, in our card business, we have tightened our lending policy to focus on applicants who may be exhibiting debt-seeking behavior.
# Title  :  Businesses
# NarrativeText  :  Commercial loans grew 9% in 2022, with most of the growth in the first half of the year. Higher inventory levels contributed to increased working capital needs, which drove higher utilization rates. However, utilization rates stabilized in the second half of the year, and current data is not pointing to additional inventory builds, which indicates most businesses are carefully managing inventory levels amid slowing demand.
# NarrativeText  :  We continue to closely monitor the most pandemic-impacted sectors and inflation-sensitive industries in our commercial portfolio. This includes:
# ListItem  :  Updating underwriting guidelines to include interest-rate
# Title  :  sensitivity to leveraged loans
# Title  :  ii
# ListItem  :  Analyzing supply chain issues, inflationary pressures, and the
# Title  :  impact of a potential recession
# ListItem  :  The Commercial Real Estate office market is showing signs of weakness due to lower demand, driving higher vacancy rates and deteriorating operating performance. Challenging economic and capital market conditions are also buffeting the office market, and while we haven’t seen this translate to significant loss content yet, we do expect to see stress over time and are proactively working with borrowers to manage our exposure. Specifically, we have issued underwriting guidance for navigating current conditions, including limited tolerance for new credit policy exceptions, increasing minimum debt yield thresholds, and stress testing and expansion of the watchlist process, including additional emphasis on the office market.
# NarrativeText  :  Looking ahead to the remainder of 2023, we are prepared for a range of scenarios. As a large lender to both consumers and businesses in the United States, we have significant credit exposure across our businesses, and as the Federal Reserve continues to take action to reduce inflation, we will continue to monitor both the markets and our own customer data and will react accordingly. If our view of economic stress deteriorates from our view at the end of 2022, we will likely add to credit loss reserves during 2023.
# NarrativeText  :  Moving forward on our risk, control, and regulatory agenda We continue to move forward with the foundational work of building out a risk and control framework appropriate for our company. This multi-year journey continues to be about setting clear priorities, cultural change, and operational execution. I have been clear and consistently reinforce that this foundational work is our top priority. This should always be the case for a bank such as ours, but this has not always been the case, so reinforcement is necessary. We remain confident in our ability to complete this work and build appropriate risk, control, and operational excellence into our culture.
# ListItem  :  The Acting Comptroller of the Currency gave an important speech in January addressing the potential difficulties of managing a large bank. Given that the OCC is a key supervisor of ours, we take the speech seriously and are focused on its key messages.
# NarrativeText  :  The speech focused on the view that there are limits to an organization’s manageability based on size and, if so, that the most efficient and effective way to fix this is to compel its simplification. I am not in a position to agree or disagree with this premise, but I am in a position to have the strong point of view that Wells Fargo is not too big or complex to manage. Our shortcomings are not structural, but they are the result of historically ineffective management and the lack of proper prioritization of building out an appropriate risk and control environment that will ultimately take multiple years to correct.
# NarrativeText  :  We are large but are far less complex than many with whom we compete. In fact, we have more similarities with regional banks than other global systemically important banks (GSIBs), and strong and effective risk management processes should scale to a company of our size. In addition, we have acted and will continue to act on our own to simplify our company and reduce operational complexity and risk, as I detail in the section later in this letter entitled “Executing on Strategic Objectives.”
# Title  :  Operating at a broad scale but with less complexity than peers
# ListItem  :  1. We are primarily a US domestic bank and we do not have the many complexities that running large-scale international businesses bring. Our legal entity structure, extent of international regulatory oversight and physical footprint are far simpler than many of our competitors. Approximately 90% of our revenues come from U.S. clients or activities of non-U.S. clients in the U.S. Our businesses outside the U.S. primarily support our U.S. customer base. We are very happy with our existing footprint and are not looking beyond for growth opportunities. 2. Our products are not complex compared with those offered by other banks and are similar to those offered by smaller institutions. We predominantly provide the same products and services as regional and smaller, more local banks. We take deposits, provide financing, move money, and provide financial advice for our customers. Our trading activities and the size of our market risk are relatively small compared to other large GSIBs. 3. Scale in each of our businesses should not make us more complex. Our distribution methods are similar to smaller institutions. We manage a branch network, have relationship managers across our markets, market through the internet, traditional advertising, direct mail, and word of mouth, and we rely on our local reputation. The controls necessary to manage a network of 4,000+ branches are similar to those necessary to manage a smaller branch network. The same is true for managing relationship managers, marketing, and protecting our reputation. Senior management should be involved at a detailed level, but all institutions should have and rely on defined control frameworks in place that are effective at risk management, regardless of individuals in a seat. These frameworks can effectively scale to a bank of our size. 4. Our customers benefit from our size and reach. Wells Fargo has nearly 4,600 retail bank branches, with a presence in 25 of the largest 30 markets in the U.S. A Wells Fargo branch or ATM is within 2 miles of over half of U.S. Census households and small businesses in our footprint. The range of banking services we provide helps us build full relationships with individuals and companies, allowing us to see a full picture of their personal, family, and/or business financial needs, and to meet these needs. We have the ability to invest in technology to make it faster, safer, and
# ListItem  :  more transparent for our customers to handle their banking needs. In addition, our resources allow us to innovate quickly, developing new products, services, and digitized experiences to meet constantly changing consumer and business expectations. These capabilities, along with our size and reach, are of tangible benefit to consumers across the country, whether they live in large cities or more rural areas, and also to the U.S. economy as a whole.
# Title  :  Managing the company with significantly heightened discipline
# NarrativeText  :  We agree that there are also traits that management should avoid as they grow. These signs are familiar to us, as we identified them as historical behaviors at Wells Fargo when I arrived. We viewed them then – as we do now – as unacceptable. Our approach today is dramatically different than it was at Wells Fargo in the past and we will continue to work so it becomes part of our culture at all levels in the organization.
# ListItem  :  1. Don’t hide behind materiality – As a large institution we know we cannot let our size hide potential issues. We must think about raw numbers, not just percentages which are indexed to a large customer base, asset base, or capital base. We have built functions and processes to review customer complaints, employee allegations, and issues raised from outside the company, and aim to use them to identify issues and themes so we can address them and make changes as required. 2. Don’t assume incidents are isolated – One of the advantages large institutions have is the amount of data and information we see and have, but we must use it expeditiously. Individual incidents provide data points which can help us learn and react, and we should treat each as such. We strive to make data-driven decisions and to explore whether incidents that can appear isolated can in fact have broader application elsewhere in the company. 3. Identify weaknesses ourselves and address them quickly – The Acting Comptroller stated that “the business of banking is operationally intensive. Even at banks with strong teams and robust risk management systems and controls, mistakes and problems can arise. Well-managed banks identify such problems early and often, address them quickly, and take steps to prevent their recurrence.” We agree completely. Many of the historical issues we continue to work through were identified by regulators, not by us. We are changing this, emphasizing our responsibility to self-identify more issues and address them with a heightened sense of urgency. As we implement our risk and control framework, we will likely identify more issues and move with haste to implement compensating and ultimately permanent controls. Our risk and control framework is not a project, but an ongoing set of actions, and it will be part of our culture. 4. Hubris, contempt, and indifference are unacceptable and dangerous traits – We cannot believe that we know better
# Title  :  2022 Annual Report
# Title  :  iii
# ListItem  :  than others and need to react with seriousness and urgency when issues are raised – whether from employees, customers, regulators, or others outside the company. Every issue raised has the opportunity to be a learning moment and we should also proactively look at our competitors to learn as well. Integration of mergers is more than a short-term technology conversion – While we have not had a merger- related systems integration in my time at Wells Fargo, we agree that “simply stitch[ing]…systems together” can cause a proliferation of issues. It is critical to merge and simplify platforms, whether merger-related or as part of a customer service strategy, as the reduced complexity in the number of platforms should make it easier to properly serve customers. For example, asking customer-service representatives to learn multiple systems to provide the same information creates more operational risk and the possibility of a poor customer experience. But these platform mergers should be the beginning of integration, not the end. This is true looking both from our perspective and the customer perspective. Customers think of us as one company, not as separate relationships with individual lines of business. They want to see their information seamlessly and be able to transact with us easily across all of their products. Unless we integrate our platforms, we will either not appear as one company to the customer, or we will create workarounds to try and accomplish this, which creates unneeded operational risk. A major competitive advantage of Wells Fargo is serving our customers across a broad range of products, but we can only do so effectively with common platforms. The same is true of data platforms. Pulling customer data from multiple platforms is operationally complex and expensive. Common data platforms across our company are critical. We rely on this for financial reporting, regulatory reporting, risk reporting, and the ability to assess a customer relationship holistically. And finally, it is a mistake to lose sight of aged platforms, to not invest in improving them and to not move to new ones. New software and hardware solutions make it easier to reduce complexity and properly serve customers, and when these solutions are part of a program with a clear target state, they should significantly reduce operational complexity. Recognizing this, Wells Fargo is implementing a modern technology stack that is cloud-native and therefore more elastic and resilient. We are applying this stack for the various product domains that we are modernizing across our businesses. Examples include a more modern digital desktop for our financial advisors in Wealth and Investment Management, our value-at-risk models in Corporate and Investment Banking, and our payment platforms across businesses. These modernization initiatives are guided top-down by a product and platform architecture that sets
# UncategorizedText  :  5.
# Title  :  iv
# ListItem  :  clear boundaries and expectations for teams. In addition to this, the hosting of our platforms is more and more migrating to a combination of private and public cloud, powered by our partnerships with Google and Microsoft. This also is leading to faster innovation by plugging in innovative services provided by these cloud providers into our platforms. In parallel to these modernization efforts, we are also enhancing the way we deliver software and the developer experience. We are implementing new cloud-native tool- chains that allow our developers to have the experience that they deserve: on-demand, instant, elastic and with embedded automated controls.
# Title  :  Further taking stock of where we stand – why haven’t we completed our risk and regulatory work
# NarrativeText  :  I am frequently asked why our risk and regulatory work is not complete though we have been publicly reprimanded, have a growth constraint, and I have been leading the company for over 3 years. I wish my job was merely to complete work that was well underway, but unfortunately this was not the case. Simply said, the work to build the appropriate risk and control infrastructure and close consent orders takes years when managed effectively, and we were not as far along as I had expected when I arrived. Much work was needed to build what is necessary to properly accomplish the work.
# NarrativeText  :  When I arrived, we did not have the culture, effective processes, or appropriate management oversight in place to remediate weaknesses on a timely basis. Today, we approach these issues differently. This management team (the broad team – not just me) has the skills and experience and is now responsible for closing our consent orders. We have changed and implemented much to put ourselves in a position to have the confidence that we can accomplish this. The specifics of our regulatory remediation plans are confidential, and while we are not where we need to be, I believe that our position is significantly improved and that we will reach our goals. We are committed to making all necessary resources available to meet our obligations.
# NarrativeText  :  I have said we are a different company today, and in this sub-section, I provide some examples.
# ListItem  :  1. When I arrived at the company in 2019, we had 12 open, public enforcement actions. Given this and the other control issues we needed to assess, it took many months to understand the depth and breadth of the weaknesses and what was required to complete the work. 2. We then went about recruiting a mostly new management team with the experience and skills that we did not sufficiently have at the company. A large portion of the Operating Committee was recruited during 2020 and they then needed to do their own assessments and develop plans. They then needed several years to build out their teams.
# ListItem  :  3. For each consent order Matters Requiring Attention (MRAs), and other control gaps identified, we needed to build detailed plans that satisfied both us and our regulators. Our plans are now detailed and have hundreds of deliverables with designated delivery dates. Many of our consent orders have work that relies on work from another order, so any slippage on one plan can impact another. Our ability to assess all of this accurately for work to be done over multiple years has not been perfect, and we have missed some deliverables, but we have learned, adjusted, and continue to move forward. 4. We needed to build processes to manage these across the company. Building reporting and setting up management review structures for these activities has been critical to moving the work forward. Most of these did not exist or were ineffective, and we now believe we have much more effective reporting and processes in place to provide appropriate oversight and allow us to identify issues early so we can course-correct. 5. We did not have the resources necessary to accomplish this work when I arrived. We have added close to 10,000 people across numerous risk- and control-related groups and have spent approximately $2 billion more in 2022 than in 2018 in these areas. We are committed to make the investments needed to complete the work. 6. And we had to build the management disciplines and culture to govern and execute such a large body of work. Our Operating Committee reviews risk and regulatory progress and escalations on a weekly basis. We provide detailed reporting to the full board and appropriate committees so they can provide oversight. These reviews are systematic and detailed, and they are helping us provide the appropriate oversight and involvement to accomplish the work.
# NarrativeText  :  I should add that we had to do all of this during the very worst of the COVID-19 pandemic. While we were not alone in dealing with the complexities of work from home, social distancing and meeting the needs of customers during a pandemic, we were alone in what we had to build, and doing so in a remote working environment increased the difficulty level significantly.
# NarrativeText  :  Some have suggested that banks view enforcement actions and fines as a cost of doing business, but I can tell you that today, nothing is further from the truth at Wells Fargo. We view any such action by our regulators as something that requires immediate management attention. We aim both to avoid the necessity of such action by doing the work ourselves and, when regulators do take enforcement action against us, we follow a disciplined process to work towards closure, again with all necessary resources available for the effort.
# NarrativeText  :  The negative impact on our reputation of having not fulfilled our obligations is clear. Simply put, failure to satisfy our regulatory requirements carries significant consequences for our company. On the other hand, fulfilling our obligations and building an
# NarrativeText  :  appropriate risk and control framework will allow us to build a strong reputation amongst a broad set of stakeholders. So why do we have so many consent orders that have been open for extended periods? Again, our historical practices were inadequate, and it has taken time to build what is necessary to change our historical inadequacies.
# NarrativeText  :  So as I look at our situation today, the failure of Wells Fargo to complete its work appropriately has resulted in multiple consent orders, fines, and an asset cap. But I can say confidently that we have taken significant actions including focusing and simplifying the company, refreshing the board, replacing most of the senior management team, and are now moving forward to correct past deficiencies. We have the willingness and the ability to complete the work.
# NarrativeText  :  And to be clear, we are committed to prioritizing this work above all else by devoting all necessary resources to the effort. Our planning is designed to ensure other activities do not interfere with this top priority. If we have a conflict, our risk and control work comes first.
# NarrativeText  :  I have said our progress will likely not be a straight line. We continue to resolve issues that were found years ago or are the result of the inadequate control environment that existed when we arrived at the company. This means that resolution of outstanding issues such as litigation, customer remediations or regulatory investigations have and could continue to have financial impacts. Additionally, until our work is complete, we will likely find new issues that need to be remediated, and these may result in additional regulatory actions.
# NarrativeText  :  Finally, as we continue to execute on our detailed plans, given the scope and complexity of our work, we may miss some interim milestones. We recognize the importance of meeting milestones that we ourselves set, but perfection is unlikely. When we discover an issue, we act quickly to course-correct and do what we can to get back on schedule. This is frustrating for us and others outside the company but is not indicative of our willingness or ability to complete our work. Rather, it is an obstacle that presents itself in nearly any large-scale, multi-year transformation.
# NarrativeText  :  When Wells Fargo faces criticism about where we stand, I understand the sentiment. I hope this section has provided detailed context and is helpful in providing an understanding of what we are doing to close our gaps. This team is taking decisive action to move our company past these issues.
# NarrativeText  :  Leadership Team Key to transforming the company, changing our culture, and realizing the full strength of our franchise is having the best management team in place. Since I joined the company in 2019, 12 of our 17 Operating Committee members are new to Wells Fargo and 15 are new to their roles. In 2022, we put in place a new Chief Auditor, a new Chief Risk Officer, a new head of Consumer Lending, and a new head of Diverse Segments, Representation and Inclusion.
# Title  :  2022 Annual Report
# Title  :  v
# NarrativeText  :  We continue to refresh our management ranks more broadly. Over 80% of our senior executive leaders – a group of approximately 150 people, most of whom report to Operating Committee members – are new to their roles since 2019, and nearly 60% are new to the company over the same time period. Over 30% of the individuals in this senior executive cohort began in new roles in 2022 or 2023. New leaders who have joined over the past several years bring important experience that is necessary for our journey.
# Title  :  Executing on Strategic Objectives
# Title  :  Simplifying our business
# NarrativeText  :  We continue to review the strategic positioning of the company and are focusing our efforts on building products and services that are core to serving our clients. This focus has led us to decisions to sell, downsize, or curtail multiple businesses. These decisions simplify the company, reduce operational complexity and risk, and allow us to focus on both our core risk and control buildout and ways to serve our customers in our core franchises. There are several examples since I joined the company in 2019.
# ListItem  :  In January 2023, we announced plans to simplify our Home Lending business and will primarily serve bank and wealth management customers as well as borrowers in minority communities. As part of this shift, we announced our plans to exit the Correspondent business, reduce the size of our Servicing portfolio, and optimize our Retail team so it aligns with our narrower customer focus. These actions will allow us to reduce risk in the Home Lending business while continuing making homeownership possible to thousands of Americans. Over the past year, we have taken several additional steps to simplify the way we operate. For instance, we have: • Implemented a cloud-native operating model which will enable us to reduce reliance on older, less stable platforms and allows us to innovate faster • Centrally organized our Control Management teams, to enable better coordination across our businesses • Streamlined our divisional leadership in Wells Fargo Advisors, moving from eight regional divisions to four • Combined Treasury Services platforms across Commercial Banking and Corporate and Investment Banking Looking further back to 2021, 2020, and 2019, we have: • Sold Wells Fargo Asset Management • Sold our Corporate Trust Services business • Sold our student lending portfolio and stopped the origination of new student loans • Exited our international wealth management segment • Sold our Canadian direct equipment finance business
# Title  :  vi
# ListItem  :  Stopped offering new home equity lines and loans
# ListItem  :  • Exited the direct Auto business • Stopped originating personal lines of credit • Sold our Institutional Retirement and Trust business • In addition, over the past several years, we have closed over a dozen representative offices globally to better focus our international business, including offices in Asia, Europe, South America, the Middle East, and elsewhere.
# ListItem  :  • In addition, over the past several years, we have closed over a dozen representative offices globally to better focus our international business, including offices in Asia, Europe, South America, the Middle East, and elsewhere. Going forward, we will continue to evaluate our businesses with an eye toward reducing complexity, increasing risk-adjusted returns, and focusing our resources on the most important products and services our customers require. Market dynamics change, the competitive environment changes, regulatory expectations evolve and we must adjust our business accordingly.
# Title  :  Focusing on customer needs and expectations
# NarrativeText  :  Each of our businesses is working to transform how we serve our customers by offering focused, innovative products and solutions. Many of the initiatives underway reduce risk in the company and we evaluate new initiatives to consider the potential impact on our control environment. Some examples are below.
# UncategorizedText  :  Our Consumer Businesses: Consumer and Small Business Banking, Consumer Lending, and Wealth and Investment Management
# ListItem  :  • We rolled out our new consumer mobile app with a simpler, more intuitive user experience which has improved customer satisfaction. We also completed the development of Fargo, our new AI-powered virtual assistant, which provides a more personalized, convenient, and simple consumer banking experience. Fargo is currently live for eligible employees and is set to begin rolling out to customers during the first half of this year. Providing such digitized services directly to our customers reduces operational complexity in our service centers and increases customer satisfaction. • We continued to improve our credit card offerings including launching two new cards – Wells Fargo Autograph and BILT. While we describe these as new products, these are actually updated products in a business we have been in for many years. • We launched Wells Fargo Premier, our new offering dedicated to the financial needs of affluent clients by bringing together our branch-based and wealth-based businesses to provide a more comprehensive, relevant, and integrated offering for our clients. • We also relaunched Intuitive Investor in our Wealth and Investment Management segment, making it easier for customers to invest with a streamlined account opening process and a lower minimum investment.
# NarrativeText  :  Our Wholesale Businesses: Commercial Banking and Corporate and Investment Banking
# ListItem  :  • We have made several hires in Corporate and Investment Banking that have received some press. These hires are in industries we currently serve and products we currently offer, but the individuals bring new expertise to Wells Fargo. • We continued to enhance the partnership within our commercial businesses to bring Corporate and Investment Banking products such as foreign exchange and M&A advisory services to our middle-market corporate clients. • In December we announced Vantage, an enhanced digital experience for our commercial and corporate clients. Vantage uses artificial intelligence and machine learning to provide a tailored and intuitive platform based on our clients’ specific needs. • Over the past year our industry-leading API platform team continued the development of payment APIs for commercial and corporate clients, invested in solutions to support our financial institution clients, ramped-up and grew product offerings in consumer lending, and began developing commercial lending solutions.
# Title  :  Evolving our approach to technology
# NarrativeText  :  Technology is helping us better serve our consumer and corporate clients. Our technology talent is modernizing platforms for our customers, clients and colleagues. Specific areas of focus are:
# NarrativeText  :  • A cross-product pricing platform
# ListItem  :  • Digitization of our lending origination platforms across Small Business, Commercial and Corporate Banking • Continued modernization of our Treasury Services and Payments platforms • Strengthening our technological capabilities in fraud prevention • Modernizing key corporate risk platforms • Refreshing our Auto loans platform
# NarrativeText  :  These enhanced digital capabilities are just the start of the initiatives we have planned as part of our multi-year digital transformation.
# Title  :  Seeing early returns from this work
# NarrativeText  :  Our work to build better, more customer-focused products and a more technology-enabled company is generating measurable returns. For instance:
# ListItem  :  • In Consumer and Small Business Banking, mobile active customers grew 4% from a year ago. • The new credit cards I mentioned above helped drive a 31% increase in new credit card accounts in 2022, and we’ve continued to maintain strong credit profiles. The average
# ListItem  :  FICO score of our new accounts in 2022 was 773, compared to 761 for the 2019 vintage. • In Wealth and Investment Management, total active Intuitive Investor accounts increased 56% from a year ago. • Our U.S. investment banking market share was 3.2% in 2022, up 61 basis points versus 2021. We had the #7 ranking in this year’s U.S. investment banking league tables, up two spots from 2021. • As a company, we deliver many solutions nowadays in sprints, reducing our through-put time by as much as 60% compared to 2020.
# NarrativeText  :  ESG, communities and customer centricity As I look back at 2022, I’m enthusiastic about the progress we’ve made in serving our communities and our customers, and I feel even better about the opportunities ahead.
# NarrativeText  :  Let me start with the changes we made during the year to help millions of customers avoid overdraft fees and meet short-term cash needs. These efforts included:
# ListItem  :  The elimination of non-sufficient funds fees and transfer fees
# ListItem  :  for customers enrolled in Overdraft Protection. • Early Pay Day, making eligible direct deposits available up to two days early. • Extra Day Grace, giving eligible customers an extra business day to make deposits to avoid overdraft fees. • And in the fourth quarter we launched Flex Loan, a new digital-only, small-dollar loan that provides eligible customers convenient and affordable access to funds. Teams from across the company came together to roll out this new product in just a few months. Though it’s still early, customer response is exceeding our expectations.
# NarrativeText  :  The above actions build on services we’ve introduced over the past several years, including Clear Access Banking, a consumer banking account with no overdraft fees. We now have over 1.7 million of those accounts, up 48% from a year ago.
# NarrativeText  :  Beyond our customers, we have an important responsibility to strengthen the communities we serve. We continued that work in 2022. This was true on several fronts.
# NarrativeText  :  Supporting homeownership
# ListItem  :  • We launched a Special Purpose Credit Program in 2022, committing $150 million to advance racial equity in homeownership, with an additional $100 million investment towards this racial equity effort announced in 2023. • We established Wealth Opportunities Restored through Homeownership, or WORTH, a $60 million national effort to address systematic barriers to homeownership for people of color. Nationally, WORTH aims to help create 40,000 new homeowners of color in eight markets by the end of 2025
# Title  :  2022 Annual Report
# Title  :  vii
# ListItem  :  • We announced an expansion of our Dream.Plan.Home closing cost credit, which provides borrowers with an income at or below 80% of the area median income where the property is located up to $5,000 to use toward closing costs. The credit is available in 16 states and in Washington, DC. • We announced Growing Diverse Housing Developers, a $40 million grant initiative focused on expanding the growth and success of real estate developers of color, including Black- and Latino-owned firms.
# NarrativeText  :  Banking inclusion
# ListItem  :  • As part of our Banking Inclusion Initiative, we launched our first Community Connections Branch outside Atlanta, with more to come. These branches offer spaces for financial health seminars and individual consultations. • Also as part of our Banking Inclusion Initiative, we announced plans with Operation HOPE to introduce HOPE Inside centers in 20 markets. HOPE Inside Centers feature financial coaches who will help empower community members to achieve their financial goals through financial education and free one-on-one coaching. To date, we’ve launched these centers in the Atlanta, Houston, Los Angeles, Oakland and Phoenix metro regions. • Since its launch in 2022, our Small Business Resource Navigator has connected nearly 1,300 small businesses to potential credit opportunities and technical assistance services provided by CDFIs.
# NarrativeText  :  Climate initiatives
# ListItem  :  • We announced interim greenhouse gas reduction targets for the Oil & Gas and Power sectors. • We issued our second Inclusive Communities and Climate Bond, a $2 billion bond that will finance projects and programs supporting housing affordability, economic opportunity, renewable energy and clean transportation.
# NarrativeText  :  In addition, we have made significant progress on our Diversity, Equity and Inclusion initiatives. These are detailed in our first Diversity, Equity, and Inclusion annual report, which we published last summer. We continue to push forward on our commitment to integrating DE&I across the company, and, as part of this commitment, we have commissioned an external, third-party Racial Equity Assessment. We plan to publish the results of the assessment by the end of this year.
# NarrativeText  :  I’m proud of all this work. We are balanced in our approach to environmental, social and governance issues, and, as I wrote a year ago, we believe that for us to be successful as a company, we must consider a broad set of stakeholders in our decisions and actions, beyond shareholders. This is not in lieu of shareholders – in fact we believe it will enhance our returns to shareholders over time. Our history has shown this to be true. Consumers and businesses want to do business with a company that has a strong reputation. A strong reputation is achieved not
# Title  :  viii
# NarrativeText  :  just from strong financial performance, but from actively supporting employees, customers, and communities – especially those most in need.
# NarrativeText  :  As we look forward I remain confident in our company. The franchise we have is enviable and will become increasingly more so as we transform the company. We have done much and we must finish the risk and control work I’ve described in a timeframe and with the quality to satisfy our regulators to take advantage of the opportunities in front of us, so this will remain our top priority.
# NarrativeText  :  We will do this while we navigate what will likely be a tricky economic environment. 2022 was a turning point in the cycle and the impact of the Federal Reserve’s interest rate increases have not been fully seen in the economy yet. Though we are starting to see the impact on consumer spend, credit, housing, and demands for goods and services, it is still early. Thus far, the impact to consumers and businesses has been manageable.
# NarrativeText  :  Though there will certainly be some industries and segments of consumers that are more impacted than others, the rate of impact we see in our customer base is not materially accelerating. This plus the strength with which consumers and businesses went into this slowing economy is a helpful set of facts as we look forward.
# NarrativeText  :  While we are not predicting a severe downturn, we must be prepared for one and we are a stronger company today than 1 and 2 years ago. We have actively managed our capital position and focused on efficiency. Our margins are wider, our returns are higher, we are better managed, and our capital position is strong. While we will be impacted by a downturn in the economic cycle, we feel prepared for a downside scenario if we see broader deterioration than we currently see or predict.
# NarrativeText  :  We still have clear opportunities to improve our performance as we make progress on our efficiency initiatives. We will invest as necessary in our risk and control infrastructure, we will modernize our existing platforms, and we will continue to make the investments necessary serve our customers through service, technology and product enhancements.
# ListItem  :  I want to conclude by thanking our employees across the company who are working hard each day to continue to make progress on our transformation. The pressure they feel to accomplish our work is immense and the dedication that I see is unmatched. I’m thankful for all that they do and remain committed to leading us towards the goal of being the most respected financial institution in the country.
# NarrativeText  :  I’m excited about all that we will accomplish in the year ahead.
# UncategorizedText  :  Charles W. Scharf Chief Executive Officer Wells Fargo & Company March 3, 2023
# Title  :  Our Performance
# Table  :  2022 2021 $ 73,785 78,492 57,282 53,831 16,503 24,661 1,534 (4,155) 13,182 21,548 12,067 20,256 3.14 4.95 1.10 0.60 3,833.8 3,885.8 3,805.2 4,061.9 3,837.0 4,096.2 $ 41.89 43.32 34.89 36.35 181,875 190,110 160,614 168,331 133,752 141,254 0.70% 1.11 7.5 12.0 9.0 14.3 78 69 $ 929,820 864,288 1,894,309 1,941,905 1,424,269 1,437,812 496,808 537,531 955,871 895,394 12,985 12,490 1,881,016 1,948,068 1,383,985 1,482,479 10.60% 11.35 $ 158,298 186,441 238,698 249,435 2020 74,264 57,630 16,634 14,129 3,377 1,786 0.43 1.22 4,144.0 4,118.0 4,134.2 39.71 32.99 185,712 164,570 136,727 0.17 1.1 1.3 78 941,788 1,941,709 1,376,011 501,207 887,637 18,516 1,952,911 1,404,381 11.59 125,066 268,531
# Title  :  $ and shares outstanding in millions, except per share amounts
# Title  :  SELECTED INCOME STATEMENT DATA
# Title  :  Total revenue
# Title  :  Noninterest expense
# Title  :  Pre-tax pre-provision profit (PTPP)1
# Title  :  Provision for credit losses
# Title  :  Wells Fargo net income
# Title  :  Wells Fargo net income applicable to common stock
# Title  :  COMMON SHARE DATA
# NarrativeText  :  Diluted earnings per common share
# NarrativeText  :  Dividends declared per common share
# Title  :  Common shares outstanding
# Title  :  Average common shares outstanding
# NarrativeText  :  Diluted average common shares outstanding
# Title  :  Book value per common share2
# Title  :  Tangible book value per common share2, 3
# UncategorizedText  :  SELECTED EQUITY DATA (PERIOD-END)
# Title  :  Total equity
# NarrativeText  :  Common stockholders’ equity
# Title  :  Tangible common equity3
# Title  :  PERFORMANCE RATIOS
# Title  :  Return on average assets (ROA)4
# Title  :  Return on average equity (ROE)5
# Title  :  Return on average tangible common equity (ROTCE)3
# Title  :  Efficiency ratio6
# UncategorizedText  :  SELECTED BALANCE SHEET DATA (AVERAGE)
# Title  :  Loans
# Title  :  Assets Deposits
# Title  :  Assets
# Title  :  Deposits
# UncategorizedText  :  SELECTED BALANCE SHEET DATA (PERIOD-END)
# Title  :  Debt securities
# Title  :  Loans
# Title  :  Allowance for loan losses
# Title  :  Assets Deposits
# Title  :  Assets
# Title  :  Deposits
# Title  :  OTHER METRICS
# Title  :  Common Equity Tier 1 (CET1) ratio7
# Title  :  Market capitalization
# Title  :  Headcount (#) (period-end)
# NarrativeText  :  1. Pre-tax pre-provision profit (PTPP) is total revenue less noninterest expense. Management believes that PTPP is a useful financial measure because it enables investors and others to assess the Company’s ability to generate capital to cover credit losses through a credit cycle. 2. Book value per common share is common stockholders’ equity divided by common shares outstanding. Tangible book value per common share is tangible common equity divided by common shares outstanding. 3. Tangible common equity, tangible book value per common share, and return on average tangible common equity are non-GAAP financial measures. For additional information, including a corresponding reconciliation to GAAP financial measures, see the “Financial Review – Capital Management – Tangible Common Equity” section in this Report. 4. Represents Wells Fargo net income divided by average assets. 5. Represents Wells Fargo net income applicable to common stock divided by average common stockholders’ equity. 6. The efficiency ratio is noninterest expense divided by total revenue (net interest income and noninterest income). 7. Represents our Common Equity Tier 1 (CET1) ratio calculated under the Standardized Approach, which is our binding CET1 ratio. For additional information, see the “Financial Review – Capital Management” section and
# UncategorizedText  :  Note 25 (Regulatory Capital Requirements and Other Restrictions) to Financial Statements in this Report.
# Title  :  Wells Fargo & Company 2022 Financial Report
# UncategorizedText  :  2
# UncategorizedText  :  7
# UncategorizedText  :  25
# UncategorizedText  :  27
# UncategorizedText  :  28
# UncategorizedText  :  52
# UncategorizedText  :  58
# UncategorizedText  :  61
# UncategorizedText  :  65
# UncategorizedText  :  67
# UncategorizedText  :  69
# UncategorizedText  :  83
# UncategorizedText  :  83
# UncategorizedText  :  83
# UncategorizedText  :  84
# UncategorizedText  :  85
# UncategorizedText  :  86
# UncategorizedText  :  87
# UncategorizedText  :  88
# UncategorizedText  :  90
# Table  :  Financial Review Overview 104 Earnings Performance 110 Balance Sheet Analysis 112 Off-Balance Sheet Arrangements 125 Risk Management 127 Capital Management 128 Regulatory Matters 130 Critical Accounting Policies 131 Current Accounting Developments 133 Forward-Looking Statements 135 Risk Factors 137 140 Controls and Procedures 148 Disclosure Controls and Procedures 158 Internal Control Over Financial Reporting 163 Management’s Report on Internal Control over 166 Financial Reporting Report of Independent Registered Public 169 Accounting Firm (KPMG LLP, Charlotte, NC, Auditor Firm ID: 185) 171 Financial Statements 174 Consolidated Statement of Income 179 Consolidated Statement of Comprehensive 181 Income Consolidated Balance Sheet 182 Consolidated Statement of Changes in Equity 184 Consolidated Statement of Cash Flows 186 Notes to Financial Statements 188 1 Summary of Significant Accounting Policies 191 2 Trading Activities 192
# Title  :  Available-for-Sale and Held-to-Maturity Debt Securities
# Title  :  Equity Securities
# Title  :  Loans and Related Allowance for Credit Losses
# Title  :  Mortgage Banking Activities
# Title  :  Intangible Assets and Other Assets
# Title  :  Leasing Activity
# Title  :  Deposits
# Title  :  Long-Term Debt
# Title  :  Preferred Stock
# Title  :  Common Stock and Stock Plans
# Title  :  Legal Actions
# Title  :  Derivatives
# Title  :  Fair Values of Assets and Liabilities
# Title  :  Securitizations and Variable Interest Entities
# Title  :  Guarantees and Other Commitments
# Title  :  Pledged Assets and Collateral
# Title  :  Operating Segments
# Title  :  Revenue and Expenses
# Title  :  Employee Benefits
# Title  :  Income Taxes
# Title  :  Earnings and Dividends Per Common Share
# Title  :  Other Comprehensive Income
# Title  :  Regulatory Capital Requirements and Other Restrictions
# Title  :  Parent-Only Financial Statements
# Title  :  Report of Independent Registered Public Accounting Firm
# UncategorizedText  :  91
# Title  :  Quarterly Financial Data
# UncategorizedText  :  103
# Title  :  Glossary of Acronyms
# Title  :  Wells Fargo & Company
# UncategorizedText  :  1
# NarrativeText  :  This Annual Report, including the Financial Review and the Financial Statements and related Notes, contains forward-looking statements, which may include forecasts of our financial results and condition, expectations for our operations and business, and our assumptions for those forecasts and expectations. Do not unduly rely on forward-looking statements. Actual results may differ materially from our forward-looking statements due to several factors. Factors that could cause our actual results to differ materially from our forward-looking statements are described in this Report, including in the “Forward-Looking Statements” section, and in the “Risk Factors” and “Regulation and Supervision” sections of our Annual Report on Form 10-K for the year ended December 31, 2022 (2022 Form 10-K).
# NarrativeText  :  When we refer to “Wells Fargo,” “the Company,” “we,” “our,” or “us” in this Report, we mean Wells Fargo & Company and Subsidiaries (consolidated). When we refer to the “Parent,” we mean Wells Fargo & Company. See the “Glossary of Acronyms” for definitions of terms used throughout this Report.
# Title  :  Financial Review
# Title  :  Overview
# NarrativeText  :  Wells Fargo & Company is a leading financial services company in assets, proudly serves one that has approximately in three U.S. households and more than 10% of small businesses in the U.S., and is a leading middle market banking provider i U.S. We provide a diversified set of banking, investment and mortgage products and services, as well as consumer and commercial finance, through our four reportable operating segments: Consumer Banking and Lending, Commercial Banking, Corporate and Investment Banking, and Wealth and Investment Management. Wells Fargo ranked No. 41 on rankings of America’s largest corporations. We ranked fourth i assets and third in the market value of our common stock among all U.S. banks at
# ListItem  :  infrastructure appropriate for its size and complexity. The Company is subject to a number of consent orders and other regulatory actions, which may require the Company, among other things, to undertake certain changes to its business, operations, products and services, and risk management practices. Addressing these regulatory actions is expected to take multiple years, and we are likely to experience issues or delays along the way in satisfying their requirements. Issues o r delays with one regulatory action could affect our progress on others, and failure to satisfy the requirements of a regulator y action on a timely basis could result in additional penalties, business restrictions, enforcement actions, and other negative consequences, which could be significant. While we still have significant work to do and have not yet satisfied certain aspec of these regulatory actions, the Company is committed to devoting the resources necessary to operate with strong business practices and controls, maintain the highest level of integrity, and have an appropriate culture in place.
# NarrativeText  :  Federal Reserve Board Consent Order Regarding Governance Oversight and Compliance and Operational Risk Management On February 2, 2018, the Company entered into a consent order with the Board of Governors of the Federal Reserve System (FRB). As required by the consent order, the Company’s Board of Directors (Board) submitted to the FRB a plan to further enhance the Board’s governance and oversight of the Company, and the Company submitted to the FRB a plan to further improve the Company’s compliance and operational risk management program. The Company continues to engage with the FRB as the Company works to address the consent order provisions. The consent order also requires the Company, following the FRB’s acceptance and approval of the plans and the Company’s adoption and implementation of the plans, to complete an initial third-party review of the enhancements and improvements
# NarrativeText  :  provided for in the plans. Until this third-party review is complete and the plans are approved and implemented to the satisfaction of the FRB, the Company’s total consolidated assets as defined under the consent order will be limited to the level as of December 31, 2017. Compliance with this asset cap is measured on a two-quarter daily average basis to allow for management of temporary fluctuations. After removal of the asset cap, a second third-party review must also be conducted to assess the efficacy and sustainability of the enhancements and improvements.
# ListItem  :  Consent Orders with the Consumer Financial Protection Bureau and Office of the Comptroller of the Currency Regarding Compliance Risk Management Program, Automobile Collateral Protection Insurance Policies, and Mortgage Interest Rate Lock Extensions On April 20, 2018, the Company entered into consent orders with the Consumer Financial Protection Bureau (CFPB) and the Office of the Comptroller of the Currency (OCC) to pay an aggregate of $1 billion in civil money penalties to resolve matters regarding the Company’s compliance risk management program and past practices involving certain automobile collateral protection insurance (CPI) policies and certain mortgage interest rate lock extensions. As required by the consent orders, the Company submitted to the CFPB and OCC an enterprise-wide compliance risk management plan and a plan to enhance the Company’s internal audit program with respect to federal consumer financial law and the terms of the consent orders. In addition, as required by the consent orders, the Company submitted for non-objection plans to remediate customers affected by the automobile collateral protection insurance and mortgage interest rate lock matters, as well as a plan for the management of remediation activities conducted by the Company. The Company continues to work to address the provisions of the consent orders. On September 9, 2021, the OCC assessed a $250 million civil money penalty against the Company related to insufficient progress in addressing requirements under the OCC’s April 2018 consent order and loss mitigation activities in the Company’s Home Lending business. On December 20, 2022, the CFPB modified its consent order to clarify how it would terminate.
# NarrativeText  :  Consent Order with the OCC Regarding Loss Mitigation Activities On September 9, 2021, the Company entered into a consent order with the OCC requiring the Company to improve the execution, risk management, and oversight of loss mitigation activities in its Home Lending business. In addition, the consent order restricts the Company from acquiring certain third-party
# UncategorizedText  :  2
# Title  :  Wells Fargo & Company

# %%
class Document:
    def __init__(self, title, parent=None, level=0):
        self.title = title
        self.elements = []
        self.parent = parent
        self.level = level
        self.children = []

    def add_element(self, element):
        self.elements.append(element)

    def add_child(self, child):
        self.children.append(child)

    def to_dict(self):
        elements = [
            {"category": element.category, "text": unidecode(element.text), "metadata": element.metadata.to_dict()}
            for element in self.elements
        ]
        return {
            "title": self.title,
            "elements": elements,
            "children": [child.to_dict() for child in self.children],
        }

# %%
"""
Helps in determining the font size of the title
"""

pages = {}
doc = fitz.open("files/2022-annual-report-wf.pdf")
api = tesserocr.PyTessBaseAPI(path="/usr/share/tesseract-ocr/5/tessdata")


def get_title_level(element):
    metadata = element.metadata

    # Load the page
    page_key = f"{metadata.filename}-{metadata.page_number}"
    if not page_key in pages:
        pages[page_key] = doc.load_page(metadata.page_number - 1)
    page = pages[page_key]

    # Get the image clip
    coords = metadata.coordinates.points
    pix = page.get_pixmap(dpi=200)
    image = Image.frombytes("RGB", [pix.width, pix.height], pix.samples).crop(
        (coords[0][0], coords[0][1], coords[2][0], coords[2][1])
    )

    api.SetImage(image)
    api.Recognize()
    iterator = api.GetIterator()

    attrs = iterator.WordFontAttributes()

    if attrs["pointsize"] < 23:
        return 3
    elif attrs["pointsize"] < 35:
        return 2
    else:
        return 1

# %%
reader = easyocr.Reader(['en'],gpu=True)

def has_image_text(image_file_name):
    return len(reader.readtext(image_file_name)) > 0

# %%
describe_prommpt = "You are an assistant tasked with summarizing tables and image for retrieval. \
    These summaries will be embedded and used to retrieve the raw table or image elements. \
    Give a concise summary of the table or image that is well optimized for retrieval:"


def get_image_description(image_file_name):
    with open(image_file_name, "rb") as f:
        image = f.read()
        response = generate(model="llava", prompt=describe_prommpt, images=[image], stream=False)
        return response["response"]

# %%
def build_documents(elements):
    global parent, pages_to_ignore

    pages_to_ignore = [11]
    regex_roman_numeral = re.compile(r"^[IVXLCDMivxlcdm]+$")

    top = Document("Wells Fargo", "")
    current_document = top

    prev_category = None

    for i, element in enumerate(elements):
        print("Processing element " , i, " from page", element.metadata.page_number, "with category", element.category)

        if element.metadata.page_number in pages_to_ignore:
            print("Ignored page", element.metadata.page_number)
            # Ignore this as this is the footer page number
            pass

        elif element.text == "2022 Annual Report" or element.text == "Wells Fargo & Company":
            print("Ignored page footer", element.text)
            # Ignore this as this is the footer text
            pass

        elif len(element.text) < 6 and (regex_roman_numeral.match(element.text) or element.text.isnumeric()):
            print("Ignored page footer", element.text)
            # Ignore this as this is the footer page number
            pass

        elif element.category == "Title":
            level = get_title_level(element)

            if prev_category == "ListItem" and level == 3 and not element.text[0].isupper():
                # This is a continuation of the previous list item
                # unstructure wrongly classified it as a title
                current_document.add_element(element)

            elif level == current_document.level:
                # Title is at the same level, so create a new document with
                # this title, and add upcoming texts in this document
                current_document = Document(element.text, current_document.parent, level)
                current_document.parent.add_child(current_document)

            elif level < current_document.level:
                # Title is of a higher level, so create a new document with
                # this title, add that to parent.parent
                # and add upcoming texts in this document
                while level <= current_document.parent.level:
                    current_document = current_document.parent
                current_document = Document(element.text, current_document.parent, level)
                current_document.parent.add_child(current_document)

            else:
                # Title is of a lower level, so create a new document with
                # this title, and add upcoming texts in this document
                current_document = Document(element.text, current_document, level)
                current_document.parent.add_child(current_document)

        elif element.category == "Text" or element.category == "NarrativeText" or element.category == "ListItem":
            current_document.add_element(element)

        elif element.category == "Table":
            element.text = get_image_description(element.metadata.image_path)
            current_document.add_element(element)

        elif element.category == "Image":
            if has_image_text(element.metadata.image_path):
                element.text = get_image_description(element.metadata.image_path)
                current_document.add_element(element)
            else:
                print("Ignored image as it has no text", element.category)

        else:
            print("Ignored element", element.category)

        prev_category = element.category

    return top

# %%
doc = build_documents(raw_pdf_elements)
# Out:
# Processing element  0  from page 62 with category Image
# Processing element  1  from page 62 with category NarrativeText
# Processing element  2  from page 62 with category NarrativeText
# Processing element  3  from page 62 with category NarrativeText
# Processing element  4  from page 62 with category UncategorizedText
# Ignored page footer 52
# Processing element  5  from page 62 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  6  from page 63 with category NarrativeText
# Processing element  7  from page 63 with category NarrativeText
# Processing element  8  from page 63 with category NarrativeText
# Processing element  9  from page 63 with category NarrativeText
# Processing element  10  from page 63 with category Title
# Processing element  11  from page 63 with category NarrativeText
# Processing element  12  from page 63 with category NarrativeText
# Processing element  13  from page 63 with category NarrativeText
# Processing element  14  from page 63 with category Table
# Processing element  15  from page 63 with category ListItem
# Processing element  16  from page 63 with category NarrativeText
# Processing element  17  from page 63 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  18  from page 63 with category UncategorizedText
# Ignored page footer 53
# Processing element  19  from page 64 with category Title
# Processing element  20  from page 64 with category NarrativeText
# Processing element  21  from page 64 with category NarrativeText
# Processing element  22  from page 64 with category Table
# Processing element  23  from page 64 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  24  from page 64 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  25  from page 64 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  26  from page 64 with category NarrativeText
# Processing element  27  from page 64 with category NarrativeText
# Processing element  28  from page 64 with category NarrativeText
# Processing element  29  from page 64 with category Title
# Processing element  30  from page 64 with category NarrativeText
# Processing element  31  from page 64 with category NarrativeText
# Processing element  32  from page 64 with category NarrativeText
# Processing element  33  from page 64 with category NarrativeText
# Processing element  34  from page 64 with category NarrativeText
# Processing element  35  from page 64 with category NarrativeText
# Processing element  36  from page 64 with category Title
# Processing element  37  from page 64 with category Title
# Processing element  38  from page 64 with category Title
# Processing element  39  from page 64 with category Title
# Processing element  40  from page 64 with category NarrativeText
# Processing element  41  from page 64 with category Title
# Processing element  42  from page 64 with category NarrativeText
# Processing element  43  from page 64 with category Title
# Processing element  44  from page 64 with category NarrativeText
# Processing element  45  from page 64 with category Title
# Processing element  46  from page 64 with category NarrativeText
# Processing element  47  from page 64 with category NarrativeText
# Processing element  48  from page 64 with category NarrativeText
# Processing element  49  from page 64 with category NarrativeText
# Processing element  50  from page 64 with category Title
# Processing element  51  from page 64 with category NarrativeText
# Processing element  52  from page 64 with category NarrativeText
# Processing element  53  from page 64 with category NarrativeText
# Processing element  54  from page 64 with category NarrativeText
# Processing element  55  from page 64 with category Table
# Processing element  56  from page 64 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  57  from page 64 with category NarrativeText
# Processing element  58  from page 64 with category UncategorizedText
# Ignored page footer 54
# Processing element  59  from page 64 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  60  from page 65 with category Title
# Processing element  61  from page 65 with category NarrativeText
# Processing element  62  from page 65 with category NarrativeText
# Processing element  63  from page 65 with category Table
# Processing element  64  from page 65 with category NarrativeText
# Processing element  65  from page 65 with category NarrativeText
# Processing element  66  from page 65 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  67  from page 65 with category NarrativeText
# Processing element  68  from page 65 with category NarrativeText
# Processing element  69  from page 65 with category Table
# Processing element  70  from page 65 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  71  from page 65 with category UncategorizedText
# Ignored page footer 55
# Processing element  72  from page 66 with category Title
# Processing element  73  from page 66 with category NarrativeText
# Processing element  74  from page 66 with category NarrativeText
# Processing element  75  from page 66 with category NarrativeText
# Processing element  76  from page 66 with category NarrativeText
# Processing element  77  from page 66 with category Table
# Processing element  78  from page 66 with category NarrativeText
# Processing element  79  from page 66 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  80  from page 66 with category NarrativeText
# Processing element  81  from page 66 with category NarrativeText
# Processing element  82  from page 66 with category NarrativeText
# Processing element  83  from page 66 with category NarrativeText
# Processing element  84  from page 66 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  85  from page 66 with category NarrativeText
# Processing element  86  from page 66 with category Table
# Processing element  87  from page 66 with category UncategorizedText
# Ignored page footer 56
# Processing element  88  from page 66 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  89  from page 66 with category UncategorizedText
# Ignored page footer 1
# Processing element  90  from page 67 with category NarrativeText
# Processing element  91  from page 67 with category NarrativeText
# Processing element  92  from page 67 with category NarrativeText
# Processing element  93  from page 67 with category NarrativeText
# Processing element  94  from page 67 with category NarrativeText
# Processing element  95  from page 67 with category Table
# Processing element  96  from page 67 with category NarrativeText
# Processing element  97  from page 67 with category Table
# Processing element  98  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  99  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  100  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  101  from page 67 with category ListItem
# Processing element  102  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  103  from page 67 with category NarrativeText
# Processing element  104  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  105  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  106  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  107  from page 67 with category NarrativeText
# Processing element  108  from page 67 with category NarrativeText
# Processing element  109  from page 67 with category Title
# Processing element  110  from page 67 with category Title
# Processing element  111  from page 67 with category Title
# Processing element  112  from page 67 with category Title
# Processing element  113  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  114  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  115  from page 67 with category NarrativeText
# Processing element  116  from page 67 with category Title
# Processing element  117  from page 67 with category NarrativeText
# Processing element  118  from page 67 with category NarrativeText
# Processing element  119  from page 67 with category Title
# Processing element  120  from page 67 with category NarrativeText
# Processing element  121  from page 67 with category NarrativeText
# Processing element  122  from page 67 with category NarrativeText
# Processing element  123  from page 67 with category Title
# Processing element  124  from page 67 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  125  from page 67 with category NarrativeText
# Processing element  126  from page 67 with category Title
# Processing element  127  from page 67 with category Title
# Processing element  128  from page 67 with category NarrativeText
# Processing element  129  from page 67 with category NarrativeText
# Processing element  130  from page 67 with category NarrativeText
# Processing element  131  from page 67 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  132  from page 67 with category UncategorizedText
# Ignored page footer 57
# Processing element  133  from page 68 with category Title
# Processing element  134  from page 68 with category NarrativeText
# Processing element  135  from page 68 with category NarrativeText
# Processing element  136  from page 68 with category NarrativeText
# Processing element  137  from page 68 with category Title
# Processing element  138  from page 68 with category NarrativeText
# Processing element  139  from page 68 with category NarrativeText
# Processing element  140  from page 68 with category ListItem
# Processing element  141  from page 68 with category ListItem
# Processing element  142  from page 68 with category ListItem
# Processing element  143  from page 68 with category ListItem
# Processing element  144  from page 68 with category NarrativeText
# Processing element  145  from page 68 with category UncategorizedText
# Ignored page footer 58
# Processing element  146  from page 68 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  147  from page 69 with category NarrativeText
# Processing element  148  from page 69 with category ListItem
# Processing element  149  from page 69 with category NarrativeText
# Processing element  150  from page 69 with category NarrativeText
# Processing element  151  from page 69 with category ListItem
# Processing element  152  from page 69 with category NarrativeText
# Processing element  153  from page 69 with category NarrativeText
# Processing element  154  from page 69 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  155  from page 69 with category UncategorizedText
# Ignored page footer 59
# Processing element  156  from page 70 with category Title
# Processing element  157  from page 70 with category NarrativeText
# Processing element  158  from page 70 with category Title
# Processing element  159  from page 70 with category ListItem
# Processing element  160  from page 70 with category ListItem
# Processing element  161  from page 70 with category ListItem
# Processing element  162  from page 70 with category ListItem
# Processing element  163  from page 70 with category ListItem
# Processing element  164  from page 70 with category UncategorizedText
# Ignored page footer 60
# Processing element  165  from page 70 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  166  from page 71 with category ListItem
# Processing element  167  from page 71 with category ListItem
# Processing element  168  from page 71 with category ListItem
# Processing element  169  from page 71 with category ListItem
# Processing element  170  from page 71 with category ListItem
# Processing element  171  from page 71 with category ListItem
# Processing element  172  from page 71 with category ListItem
# Processing element  173  from page 71 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  174  from page 71 with category UncategorizedText
# Ignored page footer 61
# Processing element  175  from page 72 with category Title
# Processing element  176  from page 72 with category ListItem
# Processing element  177  from page 72 with category NarrativeText
# Processing element  178  from page 72 with category ListItem
# Processing element  179  from page 72 with category NarrativeText
# Processing element  180  from page 72 with category NarrativeText
# Processing element  181  from page 72 with category NarrativeText
# Processing element  182  from page 72 with category NarrativeText
# Processing element  183  from page 72 with category NarrativeText
# Processing element  184  from page 72 with category NarrativeText
# Processing element  185  from page 72 with category ListItem
# Processing element  186  from page 72 with category UncategorizedText
# Ignored page footer 62
# Processing element  187  from page 72 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  188  from page 73 with category NarrativeText
# Processing element  189  from page 73 with category NarrativeText
# Processing element  190  from page 73 with category NarrativeText
# Processing element  191  from page 73 with category NarrativeText
# Processing element  192  from page 73 with category ListItem
# Processing element  193  from page 73 with category NarrativeText
# Processing element  194  from page 73 with category NarrativeText
# Processing element  195  from page 73 with category Table
# Processing element  196  from page 73 with category ListItem
# Processing element  197  from page 73 with category NarrativeText
# Processing element  198  from page 73 with category NarrativeText
# Processing element  199  from page 73 with category Title
# Processing element  200  from page 73 with category Title
# Processing element  201  from page 73 with category Title
# Processing element  202  from page 73 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  203  from page 73 with category NarrativeText
# Processing element  204  from page 73 with category NarrativeText
# Processing element  205  from page 73 with category NarrativeText
# Processing element  206  from page 73 with category NarrativeText
# Processing element  207  from page 73 with category NarrativeText
# Processing element  208  from page 73 with category NarrativeText
# Processing element  209  from page 73 with category NarrativeText
# Processing element  210  from page 73 with category NarrativeText
# Processing element  211  from page 73 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  212  from page 73 with category Title
# Processing element  213  from page 73 with category UncategorizedText
# Ignored page footer 63
# Processing element  214  from page 74 with category Title
# Processing element  215  from page 74 with category NarrativeText
# Processing element  216  from page 74 with category NarrativeText
# Processing element  217  from page 74 with category NarrativeText
# Processing element  218  from page 74 with category NarrativeText
# Processing element  219  from page 74 with category Title
# Processing element  220  from page 74 with category NarrativeText
# Processing element  221  from page 74 with category NarrativeText
# Processing element  222  from page 74 with category NarrativeText
# Processing element  223  from page 74 with category NarrativeText
# Processing element  224  from page 74 with category NarrativeText
# Processing element  225  from page 74 with category NarrativeText
# Processing element  226  from page 74 with category NarrativeText
# Processing element  227  from page 74 with category NarrativeText
# Processing element  228  from page 74 with category NarrativeText
# Processing element  229  from page 74 with category NarrativeText
# Processing element  230  from page 74 with category NarrativeText
# Processing element  231  from page 74 with category NarrativeText
# Processing element  232  from page 74 with category NarrativeText
# Processing element  233  from page 74 with category UncategorizedText
# Ignored page footer 64
# Processing element  234  from page 74 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  235  from page 75 with category NarrativeText
# Processing element  236  from page 75 with category NarrativeText
# Processing element  237  from page 75 with category ListItem
# Processing element  238  from page 75 with category Title
# Processing element  239  from page 75 with category NarrativeText
# Processing element  240  from page 75 with category NarrativeText
# Processing element  241  from page 75 with category Title
# Processing element  242  from page 75 with category Title
# Processing element  243  from page 75 with category Title
# Processing element  244  from page 75 with category NarrativeText
# Processing element  245  from page 75 with category NarrativeText
# Processing element  246  from page 75 with category NarrativeText
# Processing element  247  from page 75 with category NarrativeText
# Processing element  248  from page 75 with category NarrativeText
# Processing element  249  from page 75 with category NarrativeText
# Processing element  250  from page 75 with category NarrativeText
# Processing element  251  from page 75 with category NarrativeText
# Processing element  252  from page 75 with category NarrativeText
# Processing element  253  from page 75 with category NarrativeText
# Processing element  254  from page 75 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  255  from page 75 with category UncategorizedText
# Ignored page footer 65
# Processing element  256  from page 76 with category Title
# Processing element  257  from page 76 with category NarrativeText
# Processing element  258  from page 76 with category Table
# Processing element  259  from page 76 with category NarrativeText
# Processing element  260  from page 76 with category ListItem
# Processing element  261  from page 76 with category ListItem
# Processing element  262  from page 76 with category UncategorizedText
# Ignored page footer 66
# Processing element  263  from page 76 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  264  from page 77 with category Title
# Processing element  265  from page 77 with category ListItem
# Processing element  266  from page 77 with category ListItem
# Processing element  267  from page 77 with category ListItem
# Processing element  268  from page 77 with category ListItem
# Processing element  269  from page 77 with category ListItem
# Processing element  270  from page 77 with category ListItem
# Processing element  271  from page 77 with category ListItem
# Processing element  272  from page 77 with category ListItem
# Processing element  273  from page 77 with category ListItem
# Processing element  274  from page 77 with category ListItem
# Processing element  275  from page 77 with category ListItem
# Processing element  276  from page 77 with category ListItem
# Processing element  277  from page 77 with category ListItem
# Processing element  278  from page 77 with category ListItem
# Processing element  279  from page 77 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  280  from page 77 with category UncategorizedText
# Ignored page footer 67
# Processing element  281  from page 78 with category NarrativeText
# Processing element  282  from page 78 with category NarrativeText
# Processing element  283  from page 78 with category NarrativeText
# Processing element  284  from page 78 with category NarrativeText
# Processing element  285  from page 78 with category NarrativeText
# Processing element  286  from page 78 with category Title
# Processing element  287  from page 78 with category Title
# Processing element  288  from page 78 with category NarrativeText
# Processing element  289  from page 78 with category NarrativeText
# Processing element  290  from page 78 with category UncategorizedText
# Ignored page footer 68
# Processing element  291  from page 78 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  292  from page 78 with category Title
# Processing element  293  from page 79 with category Title
# Processing element  294  from page 79 with category NarrativeText
# Processing element  295  from page 79 with category Title
# Processing element  296  from page 79 with category NarrativeText
# Processing element  297  from page 79 with category Title
# Processing element  298  from page 79 with category Title
# Processing element  299  from page 79 with category NarrativeText
# Processing element  300  from page 79 with category NarrativeText
# Processing element  301  from page 79 with category Title
# Ignored page footer d
# Processing element  302  from page 79 with category Title
# Processing element  303  from page 79 with category Title
# Processing element  304  from page 79 with category NarrativeText
# Processing element  305  from page 79 with category ListItem
# Processing element  306  from page 79 with category NarrativeText
# Processing element  307  from page 79 with category NarrativeText
# Processing element  308  from page 79 with category NarrativeText
# Processing element  309  from page 79 with category NarrativeText
# Processing element  310  from page 79 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  311  from page 79 with category UncategorizedText
# Ignored page footer 69
# Processing element  312  from page 80 with category Title
# Processing element  313  from page 80 with category NarrativeText
# Processing element  314  from page 80 with category NarrativeText
# Processing element  315  from page 80 with category NarrativeText
# Processing element  316  from page 80 with category NarrativeText
# Processing element  317  from page 80 with category NarrativeText
# Processing element  318  from page 80 with category NarrativeText
# Processing element  319  from page 80 with category NarrativeText
# Processing element  320  from page 80 with category NarrativeText
# Processing element  321  from page 80 with category Title
# Processing element  322  from page 80 with category Title
# Processing element  323  from page 80 with category Title
# Processing element  324  from page 80 with category Title
# Processing element  325  from page 80 with category NarrativeText
# Processing element  326  from page 80 with category NarrativeText
# Processing element  327  from page 80 with category UncategorizedText
# Ignored page footer 70
# Processing element  328  from page 80 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  329  from page 81 with category NarrativeText
# Processing element  330  from page 81 with category NarrativeText
# Processing element  331  from page 81 with category NarrativeText
# Processing element  332  from page 81 with category NarrativeText
# Processing element  333  from page 81 with category NarrativeText
# Processing element  334  from page 81 with category NarrativeText
# Processing element  335  from page 81 with category ListItem
# Processing element  336  from page 81 with category NarrativeText
# Processing element  337  from page 81 with category NarrativeText
# Processing element  338  from page 81 with category ListItem
# Processing element  339  from page 81 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  340  from page 81 with category UncategorizedText
# Ignored page footer 71
# Processing element  341  from page 82 with category Title
# Processing element  342  from page 82 with category NarrativeText
# Processing element  343  from page 82 with category NarrativeText
# Processing element  344  from page 82 with category ListItem
# Processing element  345  from page 82 with category NarrativeText
# Processing element  346  from page 82 with category ListItem
# Processing element  347  from page 82 with category NarrativeText
# Processing element  348  from page 82 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  349  from page 82 with category Title
# Processing element  350  from page 82 with category NarrativeText
# Processing element  351  from page 82 with category UncategorizedText
# Ignored page footer 72
# Processing element  352  from page 82 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  353  from page 83 with category NarrativeText
# Processing element  354  from page 83 with category NarrativeText
# Processing element  355  from page 83 with category NarrativeText
# Processing element  356  from page 83 with category NarrativeText
# Processing element  357  from page 83 with category NarrativeText
# Processing element  358  from page 83 with category NarrativeText
# Processing element  359  from page 83 with category NarrativeText
# Processing element  360  from page 83 with category NarrativeText
# Processing element  361  from page 83 with category ListItem
# Processing element  362  from page 83 with category Title
# Processing element  363  from page 83 with category NarrativeText
# Processing element  364  from page 83 with category NarrativeText
# Processing element  365  from page 83 with category NarrativeText
# Processing element  366  from page 83 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  367  from page 83 with category UncategorizedText
# Ignored page footer 73
# Processing element  368  from page 84 with category Title
# Processing element  369  from page 84 with category NarrativeText
# Processing element  370  from page 84 with category NarrativeText
# Processing element  371  from page 84 with category NarrativeText
# Processing element  372  from page 84 with category NarrativeText
# Processing element  373  from page 84 with category NarrativeText
# Processing element  374  from page 84 with category NarrativeText
# Processing element  375  from page 84 with category NarrativeText
# Processing element  376  from page 84 with category NarrativeText
# Processing element  377  from page 84 with category NarrativeText
# Processing element  378  from page 84 with category NarrativeText
# Processing element  379  from page 84 with category ListItem
# Processing element  380  from page 84 with category NarrativeText
# Processing element  381  from page 84 with category UncategorizedText
# Ignored page footer 74
# Processing element  382  from page 84 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  383  from page 85 with category ListItem
# Processing element  384  from page 85 with category NarrativeText
# Processing element  385  from page 85 with category NarrativeText
# Processing element  386  from page 85 with category Title
# Processing element  387  from page 85 with category NarrativeText
# Processing element  388  from page 85 with category ListItem
# Processing element  389  from page 85 with category NarrativeText
# Processing element  390  from page 85 with category ListItem
# Processing element  391  from page 85 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  392  from page 85 with category UncategorizedText
# Ignored page footer 75
# Processing element  393  from page 86 with category Title
# Processing element  394  from page 86 with category NarrativeText
# Processing element  395  from page 86 with category NarrativeText
# Processing element  396  from page 86 with category NarrativeText
# Processing element  397  from page 86 with category NarrativeText
# Processing element  398  from page 86 with category NarrativeText
# Processing element  399  from page 86 with category ListItem
# Processing element  400  from page 86 with category Title
# Processing element  401  from page 86 with category NarrativeText
# Processing element  402  from page 86 with category Title
# Processing element  403  from page 86 with category ListItem
# Processing element  404  from page 86 with category NarrativeText
# Processing element  405  from page 86 with category Title
# Processing element  406  from page 86 with category NarrativeText
# Processing element  407  from page 86 with category UncategorizedText
# Ignored page footer 76
# Processing element  408  from page 86 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  409  from page 87 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  410  from page 87 with category NarrativeText
# Processing element  411  from page 87 with category NarrativeText
# Processing element  412  from page 87 with category ListItem
# Processing element  413  from page 87 with category NarrativeText
# Processing element  414  from page 87 with category NarrativeText
# Processing element  415  from page 87 with category NarrativeText
# Processing element  416  from page 87 with category NarrativeText
# Processing element  417  from page 87 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  418  from page 87 with category UncategorizedText
# Ignored page footer 77
# Processing element  419  from page 88 with category Title
# Processing element  420  from page 88 with category NarrativeText
# Processing element  421  from page 88 with category ListItem
# Processing element  422  from page 88 with category NarrativeText
# Processing element  423  from page 88 with category NarrativeText
# Processing element  424  from page 88 with category NarrativeText
# Processing element  425  from page 88 with category NarrativeText
# Processing element  426  from page 88 with category NarrativeText
# Processing element  427  from page 88 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  428  from page 88 with category NarrativeText
# Processing element  429  from page 88 with category UncategorizedText
# Ignored page footer 78
# Processing element  430  from page 88 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  431  from page 89 with category ListItem
# Processing element  432  from page 89 with category NarrativeText
# Processing element  433  from page 89 with category NarrativeText
# Processing element  434  from page 89 with category ListItem
# Processing element  435  from page 89 with category NarrativeText
# Processing element  436  from page 89 with category NarrativeText
# Processing element  437  from page 89 with category NarrativeText
# Processing element  438  from page 89 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  439  from page 89 with category UncategorizedText
# Ignored page footer 79
# Processing element  440  from page 90 with category Title
# Processing element  441  from page 90 with category NarrativeText
# Processing element  442  from page 90 with category ListItem
# Processing element  443  from page 90 with category NarrativeText
# Processing element  444  from page 90 with category NarrativeText
# Processing element  445  from page 90 with category NarrativeText
# Processing element  446  from page 90 with category NarrativeText
# Processing element  447  from page 90 with category NarrativeText
# Processing element  448  from page 90 with category Title
# Processing element  449  from page 90 with category NarrativeText
# Processing element  450  from page 90 with category NarrativeText
# Processing element  451  from page 90 with category NarrativeText
# Processing element  452  from page 90 with category UncategorizedText
# Ignored page footer 80
# Processing element  453  from page 90 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  454  from page 91 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  455  from page 91 with category NarrativeText
# Processing element  456  from page 91 with category NarrativeText
# Processing element  457  from page 91 with category Title
# Processing element  458  from page 91 with category Title
# Processing element  459  from page 91 with category ListItem
# Processing element  460  from page 91 with category Title
# Processing element  461  from page 91 with category NarrativeText
# Processing element  462  from page 91 with category ListItem
# Processing element  463  from page 91 with category NarrativeText
# Processing element  464  from page 91 with category NarrativeText
# Processing element  465  from page 91 with category NarrativeText
# Processing element  466  from page 91 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  467  from page 91 with category UncategorizedText
# Ignored page footer 81
# Processing element  468  from page 92 with category Title
# Processing element  469  from page 92 with category NarrativeText
# Processing element  470  from page 92 with category Title
# Processing element  471  from page 92 with category NarrativeText
# Processing element  472  from page 92 with category NarrativeText
# Processing element  473  from page 92 with category ListItem
# Processing element  474  from page 92 with category NarrativeText
# Processing element  475  from page 92 with category NarrativeText
# Processing element  476  from page 92 with category NarrativeText
# Processing element  477  from page 92 with category UncategorizedText
# Ignored page footer 82
# Processing element  478  from page 92 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  479  from page 93 with category Title
# Processing element  480  from page 93 with category Title
# Processing element  481  from page 93 with category NarrativeText
# Processing element  482  from page 93 with category Title
# Processing element  483  from page 93 with category NarrativeText
# Processing element  484  from page 93 with category ListItem
# Processing element  485  from page 93 with category NarrativeText
# Processing element  486  from page 93 with category NarrativeText
# Processing element  487  from page 93 with category NarrativeText
# Processing element  488  from page 93 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  489  from page 93 with category UncategorizedText
# Ignored page footer 83
# Processing element  490  from page 94 with category Title
# Processing element  491  from page 94 with category NarrativeText
# Processing element  492  from page 94 with category Title
# Processing element  493  from page 94 with category NarrativeText
# Processing element  494  from page 94 with category NarrativeText
# Processing element  495  from page 94 with category Title
# Processing element  496  from page 94 with category NarrativeText
# Processing element  497  from page 94 with category NarrativeText
# Processing element  498  from page 94 with category Title
# Processing element  499  from page 94 with category NarrativeText
# Processing element  500  from page 94 with category NarrativeText
# Processing element  501  from page 94 with category Image
# Processing element  502  from page 94 with category Title
# Processing element  503  from page 94 with category UncategorizedText
# Ignored page footer 84
# Processing element  504  from page 94 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  505  from page 95 with category Title
# Processing element  506  from page 95 with category Title
# Processing element  507  from page 95 with category NarrativeText
# Processing element  508  from page 95 with category Table
# Processing element  509  from page 95 with category NarrativeText
# Processing element  510  from page 95 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  511  from page 95 with category UncategorizedText
# Ignored page footer 85
# Processing element  512  from page 96 with category Title
# Processing element  513  from page 96 with category Title
# Processing element  514  from page 96 with category Table
# Processing element  515  from page 96 with category NarrativeText
# Processing element  516  from page 96 with category UncategorizedText
# Ignored page footer 86
# Processing element  517  from page 96 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  518  from page 97 with category Title
# Processing element  519  from page 97 with category Table
# Processing element  520  from page 97 with category NarrativeText
# Processing element  521  from page 97 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  522  from page 97 with category NarrativeText
# Processing element  523  from page 97 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  524  from page 97 with category UncategorizedText
# Ignored page footer 87
# Processing element  525  from page 98 with category Title
# Processing element  526  from page 98 with category Title
# Processing element  527  from page 98 with category Table
# Processing element  528  from page 98 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  529  from page 98 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  530  from page 98 with category NarrativeText
# Processing element  531  from page 98 with category NarrativeText
# Processing element  532  from page 98 with category UncategorizedText
# Ignored page footer 88
# Processing element  533  from page 98 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  534  from page 99 with category Title
# Processing element  535  from page 99 with category Title
# Processing element  536  from page 99 with category Table
# Processing element  537  from page 99 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  538  from page 99 with category NarrativeText
# Processing element  539  from page 99 with category NarrativeText
# Processing element  540  from page 99 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  541  from page 99 with category UncategorizedText
# Ignored page footer 89
# Processing element  542  from page 100 with category Title
# Processing element  543  from page 100 with category Table
# Processing element  544  from page 100 with category NarrativeText
# Processing element  545  from page 100 with category UncategorizedText
# Ignored page footer 90
# Processing element  546  from page 100 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  547  from page 101 with category Title
# Processing element  548  from page 101 with category ListItem
# Processing element  549  from page 101 with category Title
# Processing element  550  from page 101 with category NarrativeText
# Processing element  551  from page 101 with category NarrativeText
# Processing element  552  from page 101 with category ListItem
# Processing element  553  from page 101 with category ListItem
# Processing element  554  from page 101 with category NarrativeText
# Processing element  555  from page 101 with category NarrativeText
# Processing element  556  from page 101 with category NarrativeText
# Processing element  557  from page 101 with category NarrativeText
# Processing element  558  from page 101 with category NarrativeText
# Processing element  559  from page 101 with category ListItem
# Processing element  560  from page 101 with category NarrativeText
# Processing element  561  from page 101 with category NarrativeText
# Processing element  562  from page 101 with category NarrativeText
# Processing element  563  from page 101 with category NarrativeText
# Processing element  564  from page 101 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  565  from page 101 with category UncategorizedText
# Ignored page footer 91
# Processing element  566  from page 102 with category Title
# Processing element  567  from page 102 with category NarrativeText
# Processing element  568  from page 102 with category NarrativeText
# Processing element  569  from page 102 with category ListItem
# Processing element  570  from page 102 with category NarrativeText
# Processing element  571  from page 102 with category ListItem
# Processing element  572  from page 102 with category NarrativeText
# Processing element  573  from page 102 with category NarrativeText
# Processing element  574  from page 102 with category NarrativeText
# Processing element  575  from page 102 with category NarrativeText
# Processing element  576  from page 102 with category NarrativeText
# Processing element  577  from page 102 with category NarrativeText
# Processing element  578  from page 102 with category NarrativeText
# Processing element  579  from page 102 with category NarrativeText
# Processing element  580  from page 102 with category NarrativeText
# Processing element  581  from page 102 with category ListItem
# Processing element  582  from page 102 with category ListItem
# Processing element  583  from page 102 with category ListItem
# Processing element  584  from page 102 with category NarrativeText
# Processing element  585  from page 102 with category NarrativeText
# Processing element  586  from page 102 with category NarrativeText
# Processing element  587  from page 102 with category UncategorizedText
# Ignored page footer 92
# Processing element  588  from page 102 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  589  from page 103 with category NarrativeText
# Processing element  590  from page 103 with category NarrativeText
# Processing element  591  from page 103 with category NarrativeText
# Processing element  592  from page 103 with category NarrativeText
# Processing element  593  from page 103 with category NarrativeText
# Processing element  594  from page 103 with category NarrativeText
# Processing element  595  from page 103 with category NarrativeText
# Processing element  596  from page 103 with category NarrativeText
# Processing element  597  from page 103 with category NarrativeText
# Processing element  598  from page 103 with category Title
# Ignored page footer d
# Processing element  599  from page 103 with category NarrativeText
# Processing element  600  from page 103 with category NarrativeText
# Processing element  601  from page 103 with category NarrativeText
# Processing element  602  from page 103 with category NarrativeText
# Processing element  603  from page 103 with category NarrativeText
# Processing element  604  from page 103 with category NarrativeText
# Processing element  605  from page 103 with category NarrativeText
# Processing element  606  from page 103 with category NarrativeText
# Processing element  607  from page 103 with category ListItem
# Processing element  608  from page 103 with category NarrativeText
# Processing element  609  from page 103 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  610  from page 103 with category UncategorizedText
# Ignored page footer 93
# Processing element  611  from page 104 with category Title
# Processing element  612  from page 104 with category ListItem
# Processing element  613  from page 104 with category ListItem
# Processing element  614  from page 104 with category NarrativeText
# Processing element  615  from page 104 with category NarrativeText
# Processing element  616  from page 104 with category ListItem
# Processing element  617  from page 104 with category ListItem
# Processing element  618  from page 104 with category NarrativeText
# Processing element  619  from page 104 with category UncategorizedText
# Ignored page footer 94
# Processing element  620  from page 104 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  621  from page 105 with category NarrativeText
# Processing element  622  from page 105 with category NarrativeText
# Processing element  623  from page 105 with category NarrativeText
# Processing element  624  from page 105 with category NarrativeText
# Processing element  625  from page 105 with category NarrativeText
# Processing element  626  from page 105 with category NarrativeText
# Processing element  627  from page 105 with category NarrativeText
# Processing element  628  from page 105 with category NarrativeText
# Processing element  629  from page 105 with category Table
# Processing element  630  from page 105 with category NarrativeText
# Processing element  631  from page 105 with category ListItem
# Processing element  632  from page 105 with category ListItem
# Processing element  633  from page 105 with category ListItem
# Processing element  634  from page 105 with category ListItem
# Processing element  635  from page 105 with category ListItem
# Processing element  636  from page 105 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  637  from page 105 with category UncategorizedText
# Ignored page footer 95
# Processing element  638  from page 106 with category Title
# Processing element  639  from page 106 with category NarrativeText
# Processing element  640  from page 106 with category NarrativeText
# Processing element  641  from page 106 with category NarrativeText
# Processing element  642  from page 106 with category NarrativeText
# Processing element  643  from page 106 with category Title
# Processing element  644  from page 106 with category NarrativeText
# Processing element  645  from page 106 with category NarrativeText
# Processing element  646  from page 106 with category NarrativeText
# Processing element  647  from page 106 with category NarrativeText
# Processing element  648  from page 106 with category NarrativeText
# Processing element  649  from page 106 with category NarrativeText
# Processing element  650  from page 106 with category NarrativeText
# Processing element  651  from page 106 with category NarrativeText
# Processing element  652  from page 106 with category ListItem
# Processing element  653  from page 106 with category UncategorizedText
# Ignored page footer 96
# Processing element  654  from page 106 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  655  from page 107 with category Title
# Processing element  656  from page 107 with category NarrativeText
# Processing element  657  from page 107 with category NarrativeText
# Processing element  658  from page 107 with category NarrativeText
# Processing element  659  from page 107 with category NarrativeText
# Processing element  660  from page 107 with category NarrativeText
# Processing element  661  from page 107 with category NarrativeText
# Processing element  662  from page 107 with category NarrativeText
# Processing element  663  from page 107 with category NarrativeText
# Processing element  664  from page 107 with category NarrativeText
# Processing element  665  from page 107 with category NarrativeText
# Processing element  666  from page 107 with category NarrativeText
# Processing element  667  from page 107 with category NarrativeText
# Processing element  668  from page 107 with category NarrativeText
# Processing element  669  from page 107 with category NarrativeText
# Processing element  670  from page 107 with category NarrativeText
# Processing element  671  from page 107 with category NarrativeText
# Processing element  672  from page 107 with category NarrativeText
# Processing element  673  from page 107 with category NarrativeText
# Processing element  674  from page 107 with category NarrativeText
# Processing element  675  from page 107 with category NarrativeText
# Processing element  676  from page 107 with category NarrativeText
# Processing element  677  from page 107 with category NarrativeText
# Processing element  678  from page 107 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  679  from page 107 with category UncategorizedText
# Ignored page footer 97
# Processing element  680  from page 108 with category Title
# Processing element  681  from page 108 with category NarrativeText
# Processing element  682  from page 108 with category NarrativeText
# Processing element  683  from page 108 with category NarrativeText
# Processing element  684  from page 108 with category NarrativeText
# Processing element  685  from page 108 with category NarrativeText
# Processing element  686  from page 108 with category NarrativeText
# Processing element  687  from page 108 with category NarrativeText
# ...
# Ignored page footer Wells Fargo & Company
# Processing element  1845  from page 193 with category UncategorizedText
# Ignored page footer 183
# Processing element  1846  from page 194 with category Title
# Processing element  1847  from page 194 with category NarrativeText
# Processing element  1848  from page 194 with category Title
# Processing element  1849  from page 194 with category NarrativeText
# Processing element  1850  from page 194 with category ListItem
# Processing element  1851  from page 194 with category NarrativeText
# Processing element  1852  from page 194 with category NarrativeText
# Processing element  1853  from page 194 with category Table
# Processing element  1854  from page 194 with category NarrativeText
# Processing element  1855  from page 194 with category ListItem
# Processing element  1856  from page 194 with category ListItem
# Processing element  1857  from page 194 with category UncategorizedText
# Ignored page footer 184
# Processing element  1858  from page 194 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1859  from page 195 with category NarrativeText
# Processing element  1860  from page 195 with category NarrativeText
# Processing element  1861  from page 195 with category NarrativeText
# Processing element  1862  from page 195 with category NarrativeText
# Processing element  1863  from page 195 with category NarrativeText
# Processing element  1864  from page 195 with category NarrativeText
# Processing element  1865  from page 195 with category NarrativeText
# Processing element  1866  from page 195 with category Table
# Processing element  1867  from page 195 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1868  from page 195 with category UncategorizedText
# Ignored page footer 185
# Processing element  1869  from page 196 with category Title
# Processing element  1870  from page 196 with category NarrativeText
# Processing element  1871  from page 196 with category NarrativeText
# Processing element  1872  from page 196 with category Table
# Processing element  1873  from page 196 with category NarrativeText
# Processing element  1874  from page 196 with category NarrativeText
# Processing element  1875  from page 196 with category Table
# Processing element  1876  from page 196 with category UncategorizedText
# Ignored page footer 186
# Processing element  1877  from page 196 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1878  from page 197 with category NarrativeText
# Processing element  1879  from page 197 with category Table
# Processing element  1880  from page 197 with category NarrativeText
# Processing element  1881  from page 197 with category Table
# Processing element  1882  from page 197 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1883  from page 197 with category UncategorizedText
# Ignored page footer 187
# Processing element  1884  from page 198 with category Title
# Processing element  1885  from page 198 with category Title
# Processing element  1886  from page 198 with category Title
# Processing element  1887  from page 198 with category NarrativeText
# Processing element  1888  from page 198 with category NarrativeText
# Processing element  1889  from page 198 with category Title
# Processing element  1890  from page 198 with category NarrativeText
# Processing element  1891  from page 198 with category NarrativeText
# Processing element  1892  from page 198 with category Title
# Processing element  1893  from page 198 with category NarrativeText
# Processing element  1894  from page 198 with category Title
# Processing element  1895  from page 198 with category NarrativeText
# Processing element  1896  from page 198 with category NarrativeText
# Processing element  1897  from page 198 with category UncategorizedText
# Ignored page footer 188
# Processing element  1898  from page 198 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1899  from page 199 with category NarrativeText
# Processing element  1900  from page 199 with category NarrativeText
# Processing element  1901  from page 199 with category ListItem
# Processing element  1902  from page 199 with category ListItem
# Processing element  1903  from page 199 with category Title
# Processing element  1904  from page 199 with category NarrativeText
# Processing element  1905  from page 199 with category ListItem
# Processing element  1906  from page 199 with category ListItem
# Processing element  1907  from page 199 with category ListItem
# Processing element  1908  from page 199 with category ListItem
# Processing element  1909  from page 199 with category ListItem
# Processing element  1910  from page 199 with category ListItem
# Processing element  1911  from page 199 with category NarrativeText
# Processing element  1912  from page 199 with category ListItem
# Processing element  1913  from page 199 with category ListItem
# Processing element  1914  from page 199 with category Title
# Processing element  1915  from page 199 with category NarrativeText
# Processing element  1916  from page 199 with category NarrativeText
# Processing element  1917  from page 199 with category NarrativeText
# Processing element  1918  from page 199 with category ListItem
# Processing element  1919  from page 199 with category ListItem
# Processing element  1920  from page 199 with category ListItem
# Processing element  1921  from page 199 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1922  from page 199 with category UncategorizedText
# Ignored page footer 189
# Processing element  1923  from page 200 with category NarrativeText
# Processing element  1924  from page 200 with category ListItem
# Processing element  1925  from page 200 with category Title
# Processing element  1926  from page 200 with category NarrativeText
# Processing element  1927  from page 200 with category NarrativeText
# Processing element  1928  from page 200 with category NarrativeText
# Processing element  1929  from page 200 with category ListItem
# Processing element  1930  from page 200 with category ListItem
# Processing element  1931  from page 200 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1932  from page 200 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1933  from page 200 with category NarrativeText
# Processing element  1934  from page 200 with category NarrativeText
# Processing element  1935  from page 200 with category ListItem
# Processing element  1936  from page 200 with category NarrativeText
# Processing element  1937  from page 200 with category ListItem
# Processing element  1938  from page 200 with category ListItem
# Processing element  1939  from page 200 with category Image
# Processing element  1940  from page 200 with category NarrativeText
# Processing element  1941  from page 200 with category Title
# Processing element  1942  from page 200 with category UncategorizedText
# Ignored page footer 190
# Processing element  1943  from page 200 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1944  from page 201 with category Title
# Processing element  1945  from page 201 with category NarrativeText
# Processing element  1946  from page 201 with category Table
# Processing element  1947  from page 201 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1948  from page 201 with category UncategorizedText
# Ignored page footer 191
# Processing element  1949  from page 202 with category Title
# Processing element  1950  from page 202 with category Table
# Processing element  1951  from page 202 with category UncategorizedText
# Ignored page footer 192
# Processing element  1952  from page 202 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  1953  from page 203 with category Title
# Processing element  1954  from page 203 with category Title
# Processing element  1955  from page 203 with category Title
# Processing element  1956  from page 203 with category Title
# Processing element  1957  from page 203 with category Title
# Processing element  1958  from page 203 with category Title
# Processing element  1959  from page 203 with category Title
# Processing element  1960  from page 203 with category Title
# Processing element  1961  from page 203 with category Title
# Processing element  1962  from page 203 with category Title
# Processing element  1963  from page 203 with category Title
# Processing element  1964  from page 203 with category Title
# Processing element  1965  from page 203 with category Title
# Processing element  1966  from page 203 with category Title
# Processing element  1967  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1968  from page 203 with category Title
# Processing element  1969  from page 203 with category NarrativeText
# Processing element  1970  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1971  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1972  from page 203 with category Title
# Processing element  1973  from page 203 with category Title
# Processing element  1974  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1975  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1976  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1977  from page 203 with category Title
# Processing element  1978  from page 203 with category Title
# Processing element  1979  from page 203 with category Title
# Processing element  1980  from page 203 with category Title
# Processing element  1981  from page 203 with category Title
# Processing element  1982  from page 203 with category Title
# Processing element  1983  from page 203 with category NarrativeText
# Processing element  1984  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1985  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1986  from page 203 with category Title
# Processing element  1987  from page 203 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1988  from page 203 with category Title
# Processing element  1989  from page 203 with category ListItem
# Processing element  1990  from page 204 with category Title
# Processing element  1991  from page 204 with category NarrativeText
# Processing element  1992  from page 204 with category NarrativeText
# Processing element  1993  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1994  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1995  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1996  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1997  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1998  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  1999  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2000  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2001  from page 204 with category Title
# Processing element  2002  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2003  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2004  from page 204 with category Title
# Processing element  2005  from page 204 with category Title
# Processing element  2006  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2007  from page 204 with category Title
# Processing element  2008  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2009  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2010  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2011  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2012  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2013  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2014  from page 204 with category UncategorizedText
# Ignored page footer 2017
# Processing element  2015  from page 204 with category UncategorizedText
# Ignored page footer 2018
# Processing element  2016  from page 204 with category UncategorizedText
# Ignored page footer 2019
# Processing element  2017  from page 204 with category UncategorizedText
# Ignored page footer 2020
# Processing element  2018  from page 204 with category UncategorizedText
# Ignored page footer 2021
# Processing element  2019  from page 204 with category UncategorizedText
# Ignored page footer 2022
# Processing element  2020  from page 204 with category Title
# Processing element  2021  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2022  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2023  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2024  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2025  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2026  from page 204 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  2027  from page 204 with category ListItem
# Processing element  2028  from page 204 with category UncategorizedText
# Ignored page footer 100
# Processing element  2029  from page 204 with category UncategorizedText
# Ignored page footer 82
# Processing element  2030  from page 204 with category UncategorizedText
# Ignored page footer 112
# Processing element  2031  from page 204 with category UncategorizedText
# Ignored page footer 100
# Processing element  2032  from page 204 with category UncategorizedText
# Ignored page footer 139
# Processing element  2033  from page 204 with category UncategorizedText
# Ignored page footer 109
# Processing element  2034  from page 204 with category Title
# Processing element  2035  from page 204 with category Title
# Processing element  2036  from page 205 with category Title
# Processing element  2037  from page 205 with category NarrativeText
# Processing element  2038  from page 205 with category NarrativeText
# Processing element  2039  from page 205 with category NarrativeText
# Processing element  2040  from page 205 with category NarrativeText
# Processing element  2041  from page 205 with category NarrativeText
# Processing element  2042  from page 205 with category NarrativeText
# Processing element  2043  from page 205 with category NarrativeText
# Processing element  2044  from page 205 with category NarrativeText
# Processing element  2045  from page 205 with category NarrativeText
# Processing element  2046  from page 205 with category Title
# Processing element  2047  from page 205 with category NarrativeText
# Processing element  2048  from page 205 with category Title
# Processing element  2049  from page 205 with category NarrativeText
# Processing element  2050  from page 205 with category ListItem
# Processing element  2051  from page 206 with category Title
# Processing element  2052  from page 206 with category Title
# Processing element  2053  from page 206 with category Title
# Processing element  2054  from page 206 with category UncategorizedText
# Ignored element UncategorizedText

# %%
import json
with open('output.json', 'w') as f:
    json.dump(doc.to_dict(), f, indent=4)
