# %%
from langchain.text_splitter import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf
from pprint import pprint
import fitz
import tesserocr
from PIL import Image
import re
from ollama import generate
from unidecode import unidecode
import easyocr
from bs4 import BeautifulSoup
import json

# %%
# %env EXTRACT_IMAGE_BLOCK_CROP_HORIZONTAL_PAD=100
# %env EXTRACT_IMAGE_BLOCK_CROP_VERTICAL_PAD=100
# Out:
# env: EXTRACT_IMAGE_BLOCK_CROP_HORIZONTAL_PAD=100
# env: EXTRACT_IMAGE_BLOCK_CROP_VERTICAL_PAD=100

# %%
pdf_file = 'files/2022-annual-report-wf.pdf'
images_path = 'data/'
output_file = 'parsed/wf.json'

# %%
# Extract elements from PDF
def extract_pdf_elements(pdf_file, images_path):
    """
    Extract images, tables, and chunk text from a PDF file.
    path: File path to extract PDF documents
    fname: File name
    image_path: Path to save images
    """
    return partition_pdf(
        filename=pdf_file,    
        strategy='hi_res',  
        infer_table_structure=True,
        # chunking_strategy="by_title",
        hi_res_model_name = 'detectron2_onnx', 
        extract_image_block_types=["Image", "Table","Figure"],
        extract_image_block_output_dir=images_path,
        # max_characters=4000,
        # new_after_n_chars=3800,
        # combine_text_under_n_chars=2000,
    )

# %%
# Get elements
raw_pdf_elements = extract_pdf_elements(pdf_file, images_path)
# Out:
# Some weights of the model checkpoint at microsoft/table-transformer-structure-recognition were not used when initializing TableTransformerForObjectDetection: ['model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TableTransformerForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
class Document:
    def __init__(self, title, parent=None, level=0):
        self.title = title
        self.elements = []
        self.parent = parent
        self.level = level
        self.children = []

    def add_element(self, element):
        self.elements.append(element)

    def add_child(self, child):
        self.children.append(child)

    def to_dict(self):
        elements = [
            {"category": element.category, "text": unidecode(element.text), "metadata": element.metadata.to_dict()}
            for element in self.elements
        ]
        return {
            "title": self.title,
            "elements": elements,
            "children": [child.to_dict() for child in self.children],
        }

# %%
"""
Helps in determining the font size of the title
"""

pages = {}
doc = fitz.open(pdf_file)
api = tesserocr.PyTessBaseAPI(path="/usr/share/tesseract-ocr/5/tessdata")


def get_title_level(element):
    metadata = element.metadata

    # Load the page
    page_key = f"{metadata.filename}-{metadata.page_number}"
    if not page_key in pages:
        pages[page_key] = doc.load_page(metadata.page_number - 1)
    page = pages[page_key]

    # Get the image clip
    coords = metadata.coordinates.points
    pix = page.get_pixmap(dpi=200)
    image = Image.frombytes("RGB", [pix.width, pix.height], pix.samples).crop(
        (coords[0][0], coords[0][1], coords[2][0], coords[2][1])
    )

    api.SetImage(image)
    api.Recognize()
    iterator = api.GetIterator()

    attrs = iterator.WordFontAttributes()

    if attrs["pointsize"] < 23:
        return 3
    elif attrs["pointsize"] < 35:
        return 2
    else:
        return 1

# %%
reader = easyocr.Reader(['en'],gpu=True)

def has_image_text(image_file_name):
    return len(reader.readtext(image_file_name)) > 2

# %%
# The function will help to describe table & image using multimodal model
describe_prommpt = "You are an assistant tasked with summarizing tables and image for retrieval. \
    These summaries will be embedded and used to retrieve the raw table or image elements. \
    Give a concise summary of the table or image that is well optimized for retrieval:"


def get_image_description(image_file_name):
    with open(image_file_name, "rb") as f:
        image = f.read()
        response = generate(model="llava", prompt=describe_prommpt, images=[image], stream=False)
        return response["response"]

# %%
def get_last_row_text(html):
    soup = BeautifulSoup(html, "html.parser")

    rows = soup.find_all("tr")
    if len(rows) == 0:
        return None

    last_row = rows[-1]
    print(last_row)
    # Find first td/th with text
    for row in last_row.find_all(["td", "th"]):
        if row.text.strip() != "":
            return row.text.strip().replace("\n", " ")

    return None

# %%
def build_documents(elements):

    pages_to_ignore = [11]
    regex_roman_numeral = re.compile(r"^[IVXLCDMivxlcdm]+$")

    top = Document("Wells Fargo", "")
    current_document = top

    prev_category = None
    skip_till_text = None

    for i, element in enumerate(elements):
        print("Processing element ", i, " from page", element.metadata.page_number, "with category", element.category)

        if element.metadata.page_number in pages_to_ignore:
            print("Ignored page", element.metadata.page_number)
            # Ignore this as this is the footer page number
            pass

        elif skip_till_text is not None:
            print("Ignored element ", element.category, " because of skip till text: ", skip_till_text)
            if skip_till_text in element.text:
                skip_till_text = None

        elif element.text == "2022 Annual Report" or element.text == "Wells Fargo & Company":
            print("Ignored page footer", element.text)
            # Ignore this as this is the footer text
            pass

        elif len(element.text) < 6 and (regex_roman_numeral.match(element.text) or element.text.isnumeric()):
            print("Ignored page footer", element.text)
            # Ignore this as this is the footer page number
            pass

        elif element.category == "Title":
            level = get_title_level(element)

            if prev_category == "ListItem" and level == 3 and not element.text[0].isupper():
                # This is a continuation of the previous list item
                # unstructure wrongly classified it as a title
                current_document.add_element(element)

            elif level == current_document.level:
                # Title is at the same level, so create a new document with
                # this title, and add upcoming texts in this document
                current_document = Document(element.text, current_document.parent, level)
                current_document.parent.add_child(current_document)

            elif level < current_document.level:
                # Title is of a higher level, so create a new document with
                # this title, add that to parent.parent
                # and add upcoming texts in this document
                while level <= current_document.parent.level:
                    current_document = current_document.parent
                current_document = Document(element.text, current_document.parent, level)
                current_document.parent.add_child(current_document)

            else:
                # Title is of a lower level, so create a new document with
                # this title, and add upcoming texts in this document
                current_document = Document(element.text, current_document, level)
                current_document.parent.add_child(current_document)

        elif element.category == "Text" or element.category == "NarrativeText" or element.category == "ListItem":
            current_document.add_element(element)

        elif element.category == "Table":
            element.text = get_image_description(element.metadata.image_path)
            current_document.add_element(element)

            # Fetch the text in the last row of the table html
            last_row_text = get_last_row_text(element.metadata.text_as_html)
            if last_row_text is not None:
                skip_till_text = last_row_text

        elif element.category == "Image":
            if has_image_text(element.metadata.image_path):
                element.text = get_image_description(element.metadata.image_path)
                current_document.add_element(element)
            else:
                print("Ignored image as it has no text", element.category)

        else:
            print("Ignored element", element.category)

        prev_category = element.category

    return top

# %%
doc = build_documents(raw_pdf_elements)
# Out:
# Processing element  0  from page 1 with category UncategorizedText
# Ignored page footer 2022
# Processing element  1  from page 1 with category Title
# Processing element  2  from page 1 with category NarrativeText
# Ignored page footer Wells Fargo & Company
# Processing element  3  from page 1 with category Title
# Processing element  4  from page 2 with category Title
# Processing element  5  from page 2 with category NarrativeText
# Processing element  6  from page 2 with category NarrativeText
# Processing element  7  from page 2 with category Title
# Processing element  8  from page 2 with category NarrativeText
# Processing element  9  from page 2 with category NarrativeText
# Processing element  10  from page 2 with category NarrativeText
# Processing element  11  from page 2 with category NarrativeText
# Processing element  12  from page 2 with category NarrativeText
# Processing element  13  from page 2 with category NarrativeText
# Processing element  14  from page 2 with category NarrativeText
# Processing element  15  from page 2 with category NarrativeText
# Processing element  16  from page 2 with category NarrativeText
# Processing element  17  from page 2 with category NarrativeText
# Processing element  18  from page 2 with category ListItem
# Processing element  19  from page 2 with category Title
# Ignored page footer 2022 Annual Report
# Processing element  20  from page 2 with category Title
# Ignored page footer i
# Processing element  21  from page 3 with category Title
# Processing element  22  from page 3 with category Title
# Processing element  23  from page 3 with category NarrativeText
# Processing element  24  from page 3 with category NarrativeText
# Processing element  25  from page 3 with category NarrativeText
# Processing element  26  from page 3 with category Title
# Processing element  27  from page 3 with category NarrativeText
# Processing element  28  from page 3 with category NarrativeText
# Processing element  29  from page 3 with category ListItem
# Processing element  30  from page 3 with category Title
# Processing element  31  from page 3 with category Title
# Ignored page footer ii
# Processing element  32  from page 3 with category ListItem
# Processing element  33  from page 3 with category Title
# Processing element  34  from page 3 with category ListItem
# Processing element  35  from page 3 with category NarrativeText
# Processing element  36  from page 3 with category NarrativeText
# Processing element  37  from page 3 with category ListItem
# Processing element  38  from page 3 with category NarrativeText
# Processing element  39  from page 4 with category NarrativeText
# Processing element  40  from page 4 with category Title
# Processing element  41  from page 4 with category ListItem
# Processing element  42  from page 4 with category ListItem
# Processing element  43  from page 4 with category Title
# Processing element  44  from page 4 with category NarrativeText
# Processing element  45  from page 4 with category ListItem
# Processing element  46  from page 4 with category Title
# Ignored page footer 2022 Annual Report
# Processing element  47  from page 4 with category Title
# Ignored page footer iii
# Processing element  48  from page 5 with category ListItem
# Processing element  49  from page 5 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  50  from page 5 with category Title
# Ignored page footer iv
# Processing element  51  from page 5 with category ListItem
# Processing element  52  from page 5 with category Title
# Processing element  53  from page 5 with category NarrativeText
# Processing element  54  from page 5 with category NarrativeText
# Processing element  55  from page 5 with category NarrativeText
# Processing element  56  from page 5 with category ListItem
# Processing element  57  from page 6 with category ListItem
# Processing element  58  from page 6 with category NarrativeText
# Processing element  59  from page 6 with category NarrativeText
# Processing element  60  from page 6 with category NarrativeText
# Processing element  61  from page 6 with category NarrativeText
# Processing element  62  from page 6 with category NarrativeText
# Processing element  63  from page 6 with category NarrativeText
# Processing element  64  from page 6 with category NarrativeText
# Processing element  65  from page 6 with category NarrativeText
# Processing element  66  from page 6 with category NarrativeText
# Processing element  67  from page 6 with category NarrativeText
# Processing element  68  from page 6 with category Title
# Ignored page footer 2022 Annual Report
# Processing element  69  from page 6 with category Title
# Ignored page footer v
# Processing element  70  from page 7 with category NarrativeText
# Processing element  71  from page 7 with category Title
# Processing element  72  from page 7 with category Title
# Processing element  73  from page 7 with category NarrativeText
# Processing element  74  from page 7 with category ListItem
# Processing element  75  from page 7 with category Title
# Ignored page footer vi
# Processing element  76  from page 7 with category ListItem
# Processing element  77  from page 7 with category ListItem
# Processing element  78  from page 7 with category ListItem
# Processing element  79  from page 7 with category Title
# Processing element  80  from page 7 with category NarrativeText
# Processing element  81  from page 7 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  82  from page 7 with category ListItem
# Processing element  83  from page 8 with category NarrativeText
# Processing element  84  from page 8 with category ListItem
# Processing element  85  from page 8 with category Title
# Processing element  86  from page 8 with category NarrativeText
# Processing element  87  from page 8 with category NarrativeText
# Processing element  88  from page 8 with category ListItem
# Processing element  89  from page 8 with category NarrativeText
# Processing element  90  from page 8 with category Title
# Processing element  91  from page 8 with category NarrativeText
# Processing element  92  from page 8 with category ListItem
# Processing element  93  from page 8 with category ListItem
# Processing element  94  from page 8 with category NarrativeText
# Processing element  95  from page 8 with category NarrativeText
# Processing element  96  from page 8 with category ListItem
# Processing element  97  from page 8 with category ListItem
# Processing element  98  from page 8 with category NarrativeText
# Processing element  99  from page 8 with category NarrativeText
# Processing element  100  from page 8 with category NarrativeText
# Processing element  101  from page 8 with category ListItem
# Processing element  102  from page 8 with category Title
# Ignored page footer 2022 Annual Report
# Processing element  103  from page 8 with category Title
# Ignored page footer vii
# Processing element  104  from page 9 with category ListItem
# Processing element  105  from page 9 with category NarrativeText
# Processing element  106  from page 9 with category ListItem
# Processing element  107  from page 9 with category NarrativeText
# Processing element  108  from page 9 with category ListItem
# Processing element  109  from page 9 with category NarrativeText
# Processing element  110  from page 9 with category NarrativeText
# Processing element  111  from page 9 with category Title
# Ignored page footer viii
# Processing element  112  from page 9 with category NarrativeText
# Processing element  113  from page 9 with category NarrativeText
# Processing element  114  from page 9 with category NarrativeText
# Processing element  115  from page 9 with category NarrativeText
# Processing element  116  from page 9 with category NarrativeText
# Processing element  117  from page 9 with category NarrativeText
# Processing element  118  from page 9 with category ListItem
# Processing element  119  from page 9 with category NarrativeText
# Processing element  120  from page 9 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  121  from page 10 with category Title
# Processing element  122  from page 10 with category Table
# <tr><td>count (#) (period-end)</td><td></td><td>238,698</td><td>249,435</td><td>268,531</td></tr>
# Processing element  123  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  124  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  125  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  126  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  127  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  128  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  129  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  130  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  131  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  132  from page 10 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  count (#) (period-end)
# Processing element  133  from page 10 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  count (#) (period-end)
# Processing element  134  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  135  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  136  from page 10 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  count (#) (period-end)
# Processing element  137  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  138  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  139  from page 10 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  count (#) (period-end)
# Processing element  140  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  141  from page 10 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  count (#) (period-end)
# Processing element  142  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  143  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  144  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  145  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  146  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  147  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  148  from page 10 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  count (#) (period-end)
# Processing element  149  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  150  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  151  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  152  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  153  from page 10 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  count (#) (period-end)
# Processing element  154  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  155  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  156  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  157  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  158  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  159  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  160  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  161  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  162  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  163  from page 10 with category Title
# Ignored element  Title  because of skip till text:  count (#) (period-end)
# Processing element  164  from page 10 with category NarrativeText
# Processing element  165  from page 10 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  166  from page 11 with category Title
# Ignored page 11
# Processing element  167  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  168  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  169  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  170  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  171  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  172  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  173  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  174  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  175  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  176  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  177  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  178  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  179  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  180  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  181  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  182  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  183  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  184  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  185  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  186  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  187  from page 11 with category Table
# Ignored page 11
# Processing element  188  from page 11 with category Title
# Ignored page 11
# Processing element  189  from page 11 with category Title
# Ignored page 11
# Processing element  190  from page 11 with category Title
# Ignored page 11
# Processing element  191  from page 11 with category Title
# Ignored page 11
# Processing element  192  from page 11 with category Title
# Ignored page 11
# Processing element  193  from page 11 with category Title
# Ignored page 11
# Processing element  194  from page 11 with category Title
# Ignored page 11
# Processing element  195  from page 11 with category Title
# Ignored page 11
# Processing element  196  from page 11 with category Title
# Ignored page 11
# Processing element  197  from page 11 with category Title
# Ignored page 11
# Processing element  198  from page 11 with category Title
# Ignored page 11
# Processing element  199  from page 11 with category Title
# Ignored page 11
# Processing element  200  from page 11 with category Title
# Ignored page 11
# Processing element  201  from page 11 with category Title
# Ignored page 11
# Processing element  202  from page 11 with category Title
# Ignored page 11
# Processing element  203  from page 11 with category Title
# Ignored page 11
# Processing element  204  from page 11 with category Title
# Ignored page 11
# Processing element  205  from page 11 with category Title
# Ignored page 11
# Processing element  206  from page 11 with category Title
# Ignored page 11
# Processing element  207  from page 11 with category Title
# Ignored page 11
# Processing element  208  from page 11 with category Title
# Ignored page 11
# Processing element  209  from page 11 with category Title
# Ignored page 11
# Processing element  210  from page 11 with category Title
# Ignored page 11
# Processing element  211  from page 11 with category Title
# Ignored page 11
# Processing element  212  from page 11 with category Title
# Ignored page 11
# Processing element  213  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  214  from page 11 with category Title
# Ignored page 11
# Processing element  215  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  216  from page 11 with category Title
# Ignored page 11
# Processing element  217  from page 11 with category Title
# Ignored page 11
# Processing element  218  from page 11 with category UncategorizedText
# Ignored page 11
# Processing element  219  from page 12 with category NarrativeText
# Processing element  220  from page 12 with category NarrativeText
# Processing element  221  from page 12 with category Title
# Processing element  222  from page 12 with category Title
# Processing element  223  from page 12 with category NarrativeText
# Processing element  224  from page 12 with category ListItem
# Processing element  225  from page 12 with category NarrativeText
# Processing element  226  from page 12 with category NarrativeText
# Processing element  227  from page 12 with category ListItem
# Processing element  228  from page 12 with category NarrativeText
# Processing element  229  from page 12 with category UncategorizedText
# Ignored page footer 2
# Processing element  230  from page 12 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  231  from page 13 with category NarrativeText
# Processing element  232  from page 13 with category NarrativeText
# Processing element  233  from page 13 with category NarrativeText
# Processing element  234  from page 13 with category NarrativeText
# Processing element  235  from page 13 with category NarrativeText
# Processing element  236  from page 13 with category NarrativeText
# Processing element  237  from page 13 with category NarrativeText
# Processing element  238  from page 13 with category NarrativeText
# Processing element  239  from page 13 with category NarrativeText
# Processing element  240  from page 13 with category NarrativeText
# Processing element  241  from page 13 with category NarrativeText
# Processing element  242  from page 13 with category NarrativeText
# Processing element  243  from page 13 with category NarrativeText
# Processing element  244  from page 13 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  245  from page 13 with category UncategorizedText
# Ignored page footer 3
# Processing element  246  from page 14 with category NarrativeText
# Processing element  247  from page 14 with category NarrativeText
# Processing element  248  from page 14 with category NarrativeText
# Processing element  249  from page 14 with category ListItem
# Processing element  250  from page 14 with category ListItem
# Processing element  251  from page 14 with category ListItem
# Processing element  252  from page 14 with category ListItem
# Processing element  253  from page 14 with category ListItem
# Processing element  254  from page 14 with category NarrativeText
# Processing element  255  from page 14 with category ListItem
# Processing element  256  from page 14 with category ListItem
# Processing element  257  from page 14 with category ListItem
# Processing element  258  from page 14 with category NarrativeText
# Processing element  259  from page 14 with category ListItem
# Processing element  260  from page 14 with category ListItem
# Processing element  261  from page 14 with category ListItem
# Processing element  262  from page 14 with category ListItem
# Processing element  263  from page 14 with category ListItem
# Processing element  264  from page 14 with category ListItem
# Processing element  265  from page 14 with category Title
# Processing element  266  from page 14 with category NarrativeText
# Processing element  267  from page 14 with category UncategorizedText
# Ignored page footer 4
# Processing element  268  from page 14 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  269  from page 15 with category NarrativeText
# Processing element  270  from page 15 with category NarrativeText
# Processing element  271  from page 15 with category Table
# <tr><td>Total equity</td><td>181,875</td><td>190,110</td><td>(8,235)</td><td></td><td>185,712</td><td>4,398</td><td></td></tr>
# Processing element  272  from page 15 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  Total equity
# Processing element  273  from page 15 with category Title
# Ignored element  Title  because of skip till text:  Total equity
# Processing element  274  from page 15 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  Total equity
# Processing element  275  from page 16 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  Total equity
# Processing element  276  from page 16 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  Total equity
# Processing element  277  from page 16 with category Table
# Ignored element  Table  because of skip till text:  Total equity
# Processing element  278  from page 16 with category Title
# Processing element  279  from page 16 with category Title
# Processing element  280  from page 16 with category Title
# Processing element  281  from page 16 with category NarrativeText
# Processing element  282  from page 16 with category Title
# Processing element  283  from page 16 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  284  from page 16 with category NarrativeText
# Processing element  285  from page 16 with category UncategorizedText
# Ignored element UncategorizedText
# Processing element  286  from page 16 with category UncategorizedText
# Ignored page footer 6
# Processing element  287  from page 16 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  288  from page 17 with category Title
# Processing element  289  from page 17 with category NarrativeText
# Processing element  290  from page 17 with category NarrativeText
# Processing element  291  from page 17 with category NarrativeText
# Processing element  292  from page 17 with category Title
# Processing element  293  from page 17 with category NarrativeText
# Processing element  294  from page 17 with category ListItem
# Processing element  295  from page 17 with category NarrativeText
# Processing element  296  from page 17 with category Title
# Ignored page footer Wells Fargo & Company
# Processing element  297  from page 17 with category UncategorizedText
# Ignored page footer 7
# Processing element  298  from page 18 with category Title
# Processing element  299  from page 18 with category NarrativeText
# Processing element  300  from page 18 with category Table
# <tr><td></td><td>$ 1,894,309</td><td>9,074</td><td></td><td>1,941,905</td><td></td><td>3,916</td><td></td><td>1,941,709</td><td>7,964</td><td></td></tr>
# Processing element  301  from page 18 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  302  from page 18 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  303  from page 18 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  304  from page 18 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  305  from page 18 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  306  from page 19 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  307  from page 19 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  308  from page 19 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  309  from page 19 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  310  from page 19 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  311  from page 19 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  312  from page 20 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  313  from page 20 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  314  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  315  from page 20 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  316  from page 20 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  317  from page 20 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  318  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  319  from page 20 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  320  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  321  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  322  from page 20 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  323  from page 20 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  324  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  325  from page 20 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  326  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  327  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  328  from page 20 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  329  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  330  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  331  from page 20 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  332  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  333  from page 20 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  334  from page 20 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  335  from page 20 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  336  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  337  from page 21 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  338  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  339  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  340  from page 21 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  341  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  342  from page 21 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  343  from page 21 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  344  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  345  from page 21 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  346  from page 21 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  347  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  348  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  349  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  350  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  351  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  352  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  353  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  354  from page 21 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  355  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  356  from page 21 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  357  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  358  from page 21 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  359  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  360  from page 21 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  361  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  362  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  363  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  364  from page 21 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  365  from page 21 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  366  from page 21 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  367  from page 21 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  368  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  369  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  370  from page 22 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  371  from page 22 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  372  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  373  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  374  from page 22 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  375  from page 22 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  376  from page 22 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  377  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  378  from page 22 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  379  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  380  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  381  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  382  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  383  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  384  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  385  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  386  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  387  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  388  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  389  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  390  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  391  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  392  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  393  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  394  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  395  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  396  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  397  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  398  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  399  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  400  from page 22 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  401  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  402  from page 22 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  403  from page 22 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  404  from page 22 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  405  from page 23 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  406  from page 23 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  407  from page 23 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  408  from page 23 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  409  from page 23 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  410  from page 23 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  411  from page 23 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  412  from page 24 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  413  from page 24 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  414  from page 24 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  415  from page 24 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  416  from page 24 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  417  from page 24 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  418  from page 24 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  419  from page 24 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  420  from page 24 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  421  from page 24 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  422  from page 24 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  423  from page 24 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  424  from page 24 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  425  from page 24 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  426  from page 25 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  427  from page 25 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  428  from page 25 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  429  from page 25 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  430  from page 25 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  431  from page 25 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  432  from page 25 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  433  from page 25 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  434  from page 25 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  435  from page 25 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  436  from page 25 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  437  from page 25 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  438  from page 25 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  439  from page 25 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  440  from page 25 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  441  from page 26 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  442  from page 26 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  443  from page 26 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  444  from page 26 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  445  from page 26 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  446  from page 26 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  447  from page 26 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  448  from page 26 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  449  from page 26 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  450  from page 26 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  451  from page 26 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  452  from page 26 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  453  from page 26 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  454  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  455  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  456  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  457  from page 27 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  458  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  459  from page 27 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  460  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  461  from page 27 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  462  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  463  from page 27 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  464  from page 27 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  465  from page 27 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  466  from page 28 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  467  from page 28 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  468  from page 28 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  469  from page 28 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  470  from page 28 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  471  from page 28 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  472  from page 28 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  473  from page 28 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  474  from page 29 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  475  from page 29 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  476  from page 29 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  477  from page 29 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  478  from page 29 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# ...
# Processing element  2973  from page 200 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  2974  from page 200 with category Image
# Ignored element  Image  because of skip till text:  $ 1,894,309
# Processing element  2975  from page 200 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  2976  from page 200 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2977  from page 200 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  2978  from page 200 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2979  from page 201 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2980  from page 201 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  2981  from page 201 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  2982  from page 201 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2983  from page 201 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  2984  from page 202 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2985  from page 202 with category Table
# Ignored element  Table  because of skip till text:  $ 1,894,309
# Processing element  2986  from page 202 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  2987  from page 202 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2988  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2989  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2990  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2991  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2992  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2993  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2994  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2995  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2996  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2997  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2998  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  2999  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3000  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3001  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3002  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3003  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3004  from page 203 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3005  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3006  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3007  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3008  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3009  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3010  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3011  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3012  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3013  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3014  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3015  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3016  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3017  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3018  from page 203 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3019  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3020  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3021  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3022  from page 203 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3023  from page 203 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3024  from page 203 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  3025  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3026  from page 204 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3027  from page 204 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3028  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3029  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3030  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3031  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3032  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3033  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3034  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3035  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3036  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3037  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3038  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3039  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3040  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3041  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3042  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3043  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3044  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3045  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3046  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3047  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3048  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3049  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3050  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3051  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3052  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3053  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3054  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3055  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3056  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3057  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3058  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3059  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3060  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3061  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3062  from page 204 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  3063  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3064  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3065  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3066  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3067  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3068  from page 204 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309
# Processing element  3069  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3070  from page 204 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3071  from page 205 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3072  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3073  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3074  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3075  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3076  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3077  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3078  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3079  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3080  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3081  from page 205 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3082  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3083  from page 205 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3084  from page 205 with category NarrativeText
# Ignored element  NarrativeText  because of skip till text:  $ 1,894,309
# Processing element  3085  from page 205 with category ListItem
# Ignored element  ListItem  because of skip till text:  $ 1,894,309
# Processing element  3086  from page 206 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3087  from page 206 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3088  from page 206 with category Title
# Ignored element  Title  because of skip till text:  $ 1,894,309
# Processing element  3089  from page 206 with category UncategorizedText
# Ignored element  UncategorizedText  because of skip till text:  $ 1,894,309

# %%
with open(output_file, 'w') as f:
    json.dump(doc.to_dict(), f, indent=4)
